# %% [markdown]
# # 🌍 Exploring the Arabic WordNet (AWN)
#
# This notebook provides a comprehensive exploration of the Arabic WordNet using the `wn` Python library.
#
# **Arabic WordNet (AWN v2)** is part of the Open Multilingual Wordnet collection and provides Arabic lexical data linked to the Princeton WordNet through the Interlingual Index (ILI).
#
# ## Table of Contents
# 1. [Setup & Installation](#setup)
# 2. [Loading the Arabic WordNet](#loading)
# 3. [Basic Statistics](#statistics)
# 4. [Exploring Arabic Words](#words)
# 5. [Exploring Synsets](#synsets)
# 6. [Navigating the Taxonomy](#taxonomy)
# 7. [Cross-Lingual Analysis (Arabic ↔ English)](#crosslingual)
# 8. [Semantic Relations](#relations)
# 9. [Similarity Measures](#similarity)
# 10. [Advanced Analysis](#advanced)

# %% [markdown]
# <a id='setup'></a>
# ## 1. Setup & Installation

# %%
# Install wn if not already installed
# !pip install wn
# !pip install --upgrade wn
# Out:
# Requirement already satisfied: wn in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (0.9.1)
# Collecting wn
#   Using cached wn-0.14.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: httpx in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from wn) (0.28.1)
# Requirement already satisfied: anyio in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from httpx->wn) (4.11.0)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from httpx->wn) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from httpx->wn) (1.0.9)
# Requirement already satisfied: idna in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from httpx->wn) (3.10)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from httpcore==1.*->httpx->wn) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from anyio->httpx->wn) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from anyio->httpx->wn) (4.15.0)
# Using cached wn-0.14.0-py3-none-any.whl (86 kB)
# Installing collected packages: wn
#   Attempting uninstall: wn
#     Found existing installation: wn 0.9.1
#     Uninstalling wn-0.9.1:
#       Successfully uninstalled wn-0.9.1
# Successfully installed wn-0.14.0

# %%
# NOTE: If you upgraded wn and still see old version, restart the kernel:
#       Kernel → Restart Kernel (or press 0,0 in command mode)

import wn
from wn import taxonomy, similarity
from collections import Counter
import warnings

# Suppress warnings for cleaner output
warnings.filterwarnings('ignore')

print(f"wn version: {wn.__version__}")

# Should show 0.14.0 after kernel restart
# Out:
# wn version: 0.14.0

# %% [markdown]
# ### Download Required WordNets
#
# We'll download:
# - **omw-arb:1.4** - Arabic WordNet (AWN v2)
# - **omw-en:1.4** - OMW English WordNet (required for relations/taxonomy)

# %%
# Download Arabic WordNet and its English dependency
print("Downloading Arabic WordNet...")
wn.download('omw-arb:1.4')

print("\nDownloading English WordNet (for relations)...")
wn.download('omw-en:1.4')
# Out:
# Downloading Arabic WordNet...
#
# Downloading English WordNet (for relations)...
# Cached file found: /Users/salahmac/.wn_data/downloads/4cb8d2182ddb97c9a9d865fe4b0fd7c7a74d6a21
# Skipping omw-arb:1.4 (Arabic WordNet (AWN v2)); already addedc7hqf6_y/omw-arb/omw-arb.xml
#
# Cached file found: /Users/salahmac/.wn_data/downloads/3334cfd8709f5032fe246261d73528528c2542fa
# Skipping omw-en:1.4 (OMW English Wordnet based on WordNet 3.0); already addedomw-en.xml
# PosixPath('/Users/salahmac/.wn_data/downloads/3334cfd8709f5032fe246261d73528528c2542fa')

# %% [markdown]
# <a id='loading'></a>
# ## 2. Loading the Arabic WordNet

# %%
# List all installed lexicons
print("Installed Lexicons:")
print("-" * 60)
for lex in wn.lexicons():
    print(f"{lex.id:15} v{lex.version:5} [{lex.language:3}] {lex.label}")
# Out:
# Installed Lexicons:
# ------------------------------------------------------------
# omw-arb         v1.4   [arb] Arabic WordNet (AWN v2)
# omw-en          v1.4   [en ] OMW English Wordnet based on WordNet 3.0
# ewn             v2020  [en ] English WordNet
# test-lex        v1.0   [en ] Test Lexicon
# test-lex-v2     v1.0   [en ] Test Lexicon V2
# test-fe25e5     v1.0   [en ] Test

# %%
# Create Wordnet instances
arb = wn.Wordnet('omw-arb:1.4')
en = wn.Wordnet('omw-en:1.4')

# Get lexicon info
arb_lex = arb.lexicons()[0]
print("Arabic WordNet Info:")
print(f"  ID: {arb_lex.id}")
print(f"  Version: {arb_lex.version}")
print(f"  Label: {arb_lex.label}")
print(f"  Language: {arb_lex.language}")
print(f"  License: {arb_lex.license}")
# Out:
# Arabic WordNet Info:
#   ID: omw-arb
#   Version: 1.4
#   Label: Arabic WordNet (AWN v2)
#   Language: arb
#   License: https://creativecommons.org/licenses/by-sa/3.0/

# %%
# Helper function to get definitions (falls back to English via ILI)
def get_definition(synset, en_wordnet=None):
    """Get definition for a synset, falling back to English if Arabic is missing."""
    # Try Arabic definition first
    defn = synset.definition()
    if defn:
        return defn, 'ar'
    
    # Fall back to English via ILI
    if en_wordnet and synset.ili:
        en_synsets = en_wordnet.synsets(ili=synset.ili.id)
        if en_synsets:
            en_defn = en_synsets[0].definition()
            if en_defn:
                return en_defn, 'en'
    
    return "(no definition)", None

def get_english_words(synset, en_wordnet):
    """Get English word equivalents for an Arabic synset via ILI."""
    if synset.ili:
        en_synsets = en_wordnet.synsets(ili=synset.ili.id)
        if en_synsets:
            return [w.lemma() for w in en_synsets[0].words()][:5]
    return []

print("✓ Helper functions defined for cross-lingual definitions")
# Out:
# ✓ Helper functions defined for cross-lingual definitions

# %%
# Check dependencies - Arabic WN uses English WN for relations
print("Dependencies:")
print(f"  Requires: {arb_lex.requires()}")
print(f"  Expanded lexicons: {arb.expanded_lexicons()}")
# Out:
# Dependencies:
#   Requires: {'omw-en:1.4': <Lexicon omw-en:1.4 [en]>}
#   Expanded lexicons: [<Lexicon omw-en:1.4 [en]>]

# %% [markdown]
# <a id='statistics'></a>
# ## 3. Basic Statistics

# %%
def get_wordnet_stats(wordnet, name="WordNet"):
    """Calculate comprehensive statistics for a wordnet."""
    stats = {
        'name': name,
        'words': len(wordnet.words()),
        'senses': len(wordnet.senses()),
        'synsets': len(wordnet.synsets()),
    }
    
    # By part of speech
    pos_labels = {'n': 'Nouns', 'v': 'Verbs', 'a': 'Adjectives', 'r': 'Adverbs', 's': 'Adj. Satellites'}
    for pos, label in pos_labels.items():
        stats[f'words_{pos}'] = len(wordnet.words(pos=pos))
        stats[f'synsets_{pos}'] = len(wordnet.synsets(pos=pos))
    
    return stats

# Get stats for Arabic
arb_stats = get_wordnet_stats(arb, "Arabic WN")

print("📊 Arabic WordNet Statistics")
print("=" * 40)
print(f"Total Words:    {arb_stats['words']:,}")
print(f"Total Senses:   {arb_stats['senses']:,}")
print(f"Total Synsets:  {arb_stats['synsets']:,}")
print()
print("By Part of Speech:")
print("-" * 40)
print(f"  Nouns:           {arb_stats['words_n']:,} words, {arb_stats['synsets_n']:,} synsets")
print(f"  Verbs:           {arb_stats['words_v']:,} words, {arb_stats['synsets_v']:,} synsets")
print(f"  Adjectives:      {arb_stats['words_a']:,} words, {arb_stats['synsets_a']:,} synsets")
print(f"  Adverbs:         {arb_stats['words_r']:,} words, {arb_stats['synsets_r']:,} synsets")
print(f"  Adj. Satellites: {arb_stats['words_s']:,} words, {arb_stats['synsets_s']:,} synsets")
# Out:
# 📊 Arabic WordNet Statistics
# ========================================
# Total Words:    18,003
# Total Senses:   37,342
# Total Synsets:  9,916
#
# By Part of Speech:
# ----------------------------------------
#   Nouns:           10,344 words, 6,884 synsets
#   Verbs:           6,728 words, 2,484 synsets
#   Adjectives:      693 words, 443 synsets
#   Adverbs:         238 words, 105 synsets
#   Adj. Satellites: 0 words, 0 synsets

# %%
# Compare with English WordNet
en_stats = get_wordnet_stats(en, "English WN")

print("\n📈 Comparison: Arabic vs English WordNet")
print("=" * 50)
print(f"{'Metric':<20} {'Arabic':>12} {'English':>12} {'Ratio':>10}")
print("-" * 50)
for key in ['words', 'senses', 'synsets']:
    arb_val = arb_stats[key]
    en_val = en_stats[key]
    ratio = arb_val / en_val * 100 if en_val > 0 else 0
    print(f"{key.capitalize():<20} {arb_val:>12,} {en_val:>12,} {ratio:>9.1f}%")
# Out:
# 📈 Comparison: Arabic vs English WordNet
# ==================================================
# Metric                     Arabic      English      Ratio
# --------------------------------------------------
# Words                      18,003      156,584      11.5%
# Senses                     37,342      206,978      18.0%
# Synsets                     9,916      117,659       8.4%

# %%
# Polysemy analysis
def analyze_polysemy(wordnet):
    """Analyze how many senses each word has."""
    sense_counts = [len(word.senses()) for word in wordnet.words()]
    
    if not sense_counts:
        return {}
    
    return {
        'monosemous': sum(1 for c in sense_counts if c == 1),
        'polysemous': sum(1 for c in sense_counts if c > 1),
        'avg_senses': sum(sense_counts) / len(sense_counts),
        'max_senses': max(sense_counts),
        'distribution': Counter(sense_counts)
    }

polysemy = analyze_polysemy(arb)

print("\n📝 Polysemy Analysis (Arabic)")
print("=" * 40)
print(f"Monosemous words (1 sense):  {polysemy['monosemous']:,}")
print(f"Polysemous words (>1 sense): {polysemy['polysemous']:,}")
print(f"Average senses per word:     {polysemy['avg_senses']:.2f}")
print(f"Maximum senses for a word:   {polysemy['max_senses']}")

print("\nSense count distribution (top 10):")
for count, freq in sorted(polysemy['distribution'].items())[:10]:
    bar = '█' * min(freq // 100, 50)
    print(f"  {count} sense(s): {freq:>5} words {bar}")
# Out:
# 📝 Polysemy Analysis (Arabic)
# ========================================
# Monosemous words (1 sense):  12,591
# Polysemous words (>1 sense): 5,412
# Average senses per word:     2.07
# Maximum senses for a word:   48
#
# Sense count distribution (top 10):
#   1 sense(s): 12591 words ██████████████████████████████████████████████████
#   2 sense(s):  2288 words ██████████████████████
#   3 sense(s):  1075 words ██████████
#   4 sense(s):   625 words ██████
#   5 sense(s):   337 words ███
#   6 sense(s):   219 words ██
#   7 sense(s):   141 words █
#   8 sense(s):   130 words █
#   9 sense(s):    85 words
#   10 sense(s):    66 words

# %% [markdown]
# <a id='words'></a>
# ## 4. Exploring Arabic Words

# %%
# Sample some Arabic words
print("📚 Sample Arabic Words")
print("=" * 60)

sample_words = list(arb.words())[:20]
for word in sample_words:
    senses = word.senses()
    print(f"  {word.lemma():20} (POS: {word.pos}) - {len(senses)} sense(s)")
# Out:
# 📚 Sample Arabic Words
# ============================================================
#   أوّلِي               (POS: a) - 1 sense(s)
#   ظلْماء               (POS: n) - 1 sense(s)
#   دُهْمة               (POS: n) - 1 sense(s)
#   كِيْلُو مِتْر        (POS: n) - 1 sense(s)
#   شارِي                (POS: n) - 1 sense(s)
#   شائِك الجِلْد        (POS: n) - 1 sense(s)
#   شذا                  (POS: n) - 1 sense(s)
#   شأن                  (POS: n) - 5 sense(s)
#   شأْن                 (POS: n) - 1 sense(s)
#   شاء                  (POS: v) - 3 sense(s)
#   شاذّ                 (POS: n) - 1 sense(s)
#   شاع                  (POS: v) - 2 sense(s)
#   شاعِر                (POS: n) - 1 sense(s)
#   شاحِنة               (POS: n) - 1 sense(s)
#   شاطر                 (POS: v) - 3 sense(s)
#   شاطر الأسى           (POS: v) - 1 sense(s)
#   شاطِئ                (POS: n) - 2 sense(s)
#   شاطِئ البحْر         (POS: n) - 1 sense(s)
#   شاب                  (POS: n) - 1 sense(s)
#   شاب                  (POS: a) - 1 sense(s)

# %%
# Look up specific Arabic words
# Common Arabic words to explore
test_words = ['كتاب', 'ماء', 'شمس', 'قمر', 'بيت', 'حب', 'علم', 'عمل', 'كبير', 'صغير']

print("🔍 Looking up Common Arabic Words")
print("=" * 70)

for arabic_word in test_words:
    words = arb.words(arabic_word)
    if words:
        for word in words:
            print(f"\n✓ {word.lemma()} (POS: {word.pos})")
            for sense in word.senses():
                synset = sense.synset()
                defn, lang = get_definition(synset, en)
                en_words = get_english_words(synset, en)
                
                # Format output with language indicator and English words
                lang_tag = f"[{lang}]" if lang else ""
                en_tag = f" ({', '.join(en_words[:3])})" if en_words else ""
                
                display_defn = f"{defn[:55]}..." if len(defn) > 55 else defn
                print(f"    → {lang_tag} {display_defn}{en_tag}")
    else:
        print(f"\n✗ '{arabic_word}' not found")
# Out:
# 🔍 Looking up Common Arabic Words
# ======================================================================
#
# ✓ كِتاب (POS: n)
#     → [en] a written message addressed to a person or organization (letter, missive)
#     → [en] a written work or composition that has been published (... (book)
#     → [en] a number of sheets (ticket or stamps etc.) bound togeth... (book)
#     → [en] physical objects consisting of a number of pages bound ... (book, volume)
#     → [en] a major division of a long written composition (book)
#
# ✓ ماء (POS: n)
#     → [en] once thought to be one of four elements composing the u... (water)
#     → [en] liquid excretory product (urine, piss, pee)
#     → [en] a facility that provides a source of water (water system, water supply, water)
#     → [en] binary compound that occurs at room temperature as a cl... (water, H2O)
#     → [en] the part of the earth's surface covered with water (suc... (body of water, water)
#     → [en] a liquid necessary for the life of most animals and pla... (water)
#
# ✓ شمْس (POS: n)
#     → [en] the rays of the sun (sunlight, sunshine, sun)
#     → [en] the star that is the source of light and heat for the p... (sun, Sun)
#
# ✓ قمر (POS: n)
#     → [en] any object resembling a moon (moon)
#     → [en] the light of the Moon (moonlight, moonshine, Moon)
#     → [en] any natural satellite of a planet (moon)
#
# ✓ بيْت (POS: n)
#     → [en] where you live at a particular time (home, place)
#     → [en] a building in which something is sheltered or located (house)
#     → [en] an environment offering affection and security (home)
#     → [en] any address at which you dwell more than temporarily (residence, abode)
#     → [en] housing that someone is living in (dwelling, home, domicile)
#     → [en] a dwelling that serves as living quarters for one or mo... (house)
#
# ✓ بَيْت (POS: n)
#     → [en] a social unit living together (family, household, house)
#     → [en] the members of a religious community living together (house)
#
# ✓ حبّ (POS: n)
#     → [en] grass whose starchy grains are used as food: wheat; ric... (cereal, cereal grass)
#
# ✓ حُبْ (POS: n)
#     → [en] a positive feeling of liking (affection, affectionateness, fondness)
#
# ✓ حُبّ (POS: n)
#     → [en] a beloved person; used as terms of endearment (beloved, dear, dearest)
#     → [en] a strong positive emotion of regard and affection (love)
#     → [en] any object of warm affection or devotion (love, passion)
#
# ✓ حب (POS: v)
#     → [en] prefer or wish to do something (wish, care, like)
#     → [en] want to have (like)
#     → [en] feel about or towards; consider, evaluate, or regard (like)
#     → [en] cause to be attached (attach)
#
# ✓ علّم (POS: v)
#     → [en] place signs, as along a road (sign)
#     → [en] accustom gradually to some action or attitude (teach)
#     → [en] teach or refine to be discriminative in taste or judgme... (educate, school, train)
#     → [en] insert punctuation marks into (punctuate, mark)
#     → [en] make or leave a mark on (mark)
#     → [en] designate as if by a mark (mark)
#     → [en] attach a tag or label to (tag, label, mark)
#     → [en] impart skills or knowledge to (teach, learn, instruct)
#     → [en] give religious instructions to (catechize, catechise)
#     → [en] to stress, single out as important (stress, emphasize, emphasise)
#
# ✓ علِم (POS: v)
#     → [en] be cognizant or aware of a fact or a specific piece of ... (know, cognize, cognise)
#     → [en] get to know or become aware of, usually accidentally (learn, hear, get word)
#     → [en] find out, learn, or determine with certainty, usually b... (determine, check, find out)
#
# ✓ عِلْم (POS: n)
#     → [en] having knowledge of (awareness, consciousness, cognizance)
#     → [en] a particular branch of scientific knowledge (science, scientific discipline)
#
# ✓ علم (POS: n)
#     → [en] emblem usually consisting of a rectangular piece of clo... (flag)
#
# ✓ علم (POS: v)
#     → [en] look at, interpret, and say out loud something that is ... (read)
#     → [en] make publicity for; try to sell (a product) (advertise, advertize, promote)
#     → [en] impart knowledge of some fact, state or affairs, or eve... (inform)
#     → [en] make or leave a mark on (mark)
#     → [en] call attention to (advertise, publicize, advertize)
#     → [en] take up residence and become established (settle, locate)
#     → [en] be aware of the truth of something; have a belief or fa... (know)
#     → [en] have sexual intercourse with (sleep together, roll in the hay, love)
#     → [en] be cognizant or aware of a fact or a specific piece of ... (know, cognize, cognise)
#     → [en] teach or refine to be discriminative in taste or judgme... (educate, school, train)
#     → [en] be a student of a certain subject (learn, study, read)
#     → [en] inform (somebody) of something (advise, notify, give notice)
#     → [en] make aware of (instruct, apprise, apprize)
#     → [en] interpret something that is written or printed (read)
#     → [en] impart skills or knowledge to (teach, learn, instruct)
#     → [en] admit (to a wrongdoing) (concede, profess, confess)
#     → [en] learn by repetition (drill, exercise, practice)
#     → [en] give advice to (rede, advise, counsel)
#     → [en] interpret something in a certain way; convey a particul... (take, read)
#     → [en] obtain data from magnetic tapes (read, scan)
#
# ✓ عمل (POS: n)
#     → [en] the trait of being active; moving or acting rapidly and... (activeness, activity)
#     → [en] a military engagement (military action, action)
#     → [en] a place where work is done (workplace, work)
#     → [en] the principal activity in your life that you do to earn... (occupation, business, job)
#     → [en] something that people do or cause to happen (act, deed, human action)
#     → [en] a notable achievement (feat, effort, exploit)
#     → [en] process or manner of functioning or operating (operation, functioning, performance)
#     → [en] something done (usually as opposed to something said) (action)
#     → [en] productive work (especially physical work done for wage... (labor, labour, toil)
#     → [en] the total output of a writer or artist (or a substantia... (oeuvre, work, body of work)
#     → [en] the occupation for which you are paid (employment, work)
#     → [en] a product produced or accomplished through the effort o... (work, piece of work)
#     → [en] what something is used for (function, purpose, role)
#     → [en] a specific piece of work required to be done as a duty ... (job, task, chore)
#     → [en] any piece of work that is undertaken or attempted (undertaking, project, task)
#     → [en] the volume of commercial activity (business)
#     → [en] the state of being active (action, activity, activeness)
#     → [en] activity directed toward making or doing something (work)
#
# ✓ عمل (POS: v)
#     → [en] make sense of; assign a meaning to (interpret, construe, see)
#     → [en] come together (meet, run into, encounter)
#     → [en] go to see a place, as for entertainment (visit, see)
#     → [en] get (something) done (do, perform)
#     → [en] go or live through (experience, see, go through)
#     → [en] deem to be (see, consider, reckon)
#     → [en] imagine; conceive of; see in one's mind (visualize, visualise, envision)
#     → [en] observe, check out, and look over carefully or inspect (examine, see)
#     → [en] get to know or become aware of, usually accidentally (learn, hear, get word)
#     → [en] perceive by sight or have the power to perceive by sigh... (see)
#
# ✓ عملْ (POS: n)
#     → [en] employment in or work for another (service)
#
# ✓ عمِل (POS: v)
#     → [en] exert oneself by doing mental or physical work for a pu... (work)
#     → [en] perform as expected when applied (function, work, operate)
#     → [en] be employed (work, do work)
#     → [en] proceed towards a goal or along a path or through an ac... (work)
#     → [en] shape, form, or improve a material (work, work on, process)
#     → [en] organize or be responsible for (hold, throw, have)
#     → [en] engage in (make, do)
#     → [en] direct the course of; manage or control (conduct, carry on, deal)
#     → [en] behave in a certain manner; show a certain behavior; co... (act, behave, do)
#     → [en] perform or carry out (make)
#     → [en] work hard (labor, labour, toil)
#
# ✓ كبِير (POS: a)
#     → [en] above average in size or number or quantity or magnitud... (large, big)
#
# ✓ صغِير (POS: n)
#     → [en] an immature childish person (child, baby)
#     → [en] any immature animal (young, offspring)
#     → [en] a young person of either sex (child, kid, youngster)
#
# ✓ صَغِير (POS: n)
#     → [en] the young of an animal cared for at one time (brood)

# %%
# Find the most polysemous Arabic words
print("\n🏆 Most Polysemous Arabic Words")
print("=" * 50)

word_senses = [(word, len(word.senses())) for word in arb.words()]
word_senses.sort(key=lambda x: x[1], reverse=True)

for word, num_senses in word_senses[:15]:
    print(f"  {word.lemma():25} - {num_senses} senses")
# Out:
# 🏆 Most Polysemous Arabic Words
# ==================================================
#   أدرك                      - 48 senses
#   أثار                      - 47 senses
#   فصل                       - 46 senses
#   حمل                       - 45 senses
#   حقق                       - 45 senses
#   رافق                      - 44 senses
#   حول                       - 43 senses
#   نشر                       - 42 senses
#   حدث                       - 41 senses
#   ظهر                       - 41 senses
#   ترك                       - 41 senses
#   عبر                       - 39 senses
#   رحل                       - 39 senses
#   وقع                       - 39 senses
#   فهم                       - 38 senses

# %% [markdown]
# ## 🔬 Deep Dive: Highly Polysemous Words (8+ Senses)
#
# Let's explore words that have many meanings (polysemy). Words with 8 or more senses are particularly interesting as they often represent core vocabulary with rich semantic extensions.

# %%
# Explore highly polysemous words (8+ senses)
print("🔬 Deep Dive: Words with 8+ Senses")
print("=" * 70)

# Find words with 8 or more senses
highly_polysemous = [(word, len(word.senses())) for word in arb.words() if len(word.senses()) >= 8]
highly_polysemous.sort(key=lambda x: x[1], reverse=True)

print(f"Found {len(highly_polysemous)} words with 8+ senses\n")

for word, num_senses in highly_polysemous:
    print(f"\n{'='*70}")
    print(f"📝 {word.lemma()} ({word.pos}) - {num_senses} senses")
    print("=" * 70)
    
    for i, sense in enumerate(word.senses(), 1):
        synset = sense.synset()
        defn, lang = get_definition(synset, en)
        en_words = get_english_words(synset, en)
        
        # Format English equivalent
        en_equiv = f" → EN: {', '.join(en_words[:3])}" if en_words else ""
        lang_tag = f"[{lang}]" if lang else ""
        
        print(f"\n  Sense {i}:{en_equiv}")
        print(f"    Definition {lang_tag}: {defn[:75]}{'...' if len(defn) > 75 else ''}")
        
        # Show examples if available
        examples = synset.examples()
        if examples:
            print(f"    Example: {examples[0][:60]}{'...' if len(str(examples[0])) > 60 else ''}")
# Out:
# 🔬 Deep Dive: Words with 8+ Senses
# ======================================================================
# Found 727 words with 8+ senses
#
#
# ======================================================================
# 📝 أدرك (v) - 48 senses
# ======================================================================
#
#   Sense 1: → EN: feel
#     Definition [en]: have a feeling or perception about oneself in reaction to someone's behavio...
#
#   Sense 2: → EN: learn, hear, get word
#     Definition [en]: get to know or become aware of, usually accidentally
#
#   Sense 3: → EN: follow, fall out
#     Definition [en]: come as a logical consequence; follow logically
#
#   Sense 4: → EN: pass, overtake, overhaul
#     Definition [en]: travel past
#
#   Sense 5: → EN: meet, run into, encounter
#     Definition [en]: come together
#
#   Sense 6: → EN: recognize, recognise, realize
#     Definition [en]: be fully aware or cognizant of
#
#   Sense 7: → EN: recognize, recognise
#     Definition [en]: show approval or appreciation of
#
#   Sense 8: → EN: recognize, recognise
#     Definition [en]: perceive to be the same
#
#   Sense 9: → EN: see
#     Definition [en]: perceive by sight or have the power to perceive by sight
#
#   Sense 10: → EN: grok, get the picture, comprehend
#     Definition [en]: get the meaning of something
#
#   Sense 11: → EN: bring, convey, take
#     Definition [en]: take something or somebody with oneself somewhere
#
#   Sense 12: → EN: choose, take, select
#     Definition [en]: pick out, select, or choose from a number of alternatives
#
#   Sense 13: → EN: examine, see
#     Definition [en]: observe, check out, and look over carefully or inspect
#
#   Sense 14: → EN: take, read
#     Definition [en]: interpret something in a certain way; convey a particular meaning or impres...
#
#   Sense 15: → EN: accept, take, have
#     Definition [en]: receive willingly something given or offered
#
#   Sense 16: → EN: visualize, visualise, envision
#     Definition [en]: imagine; conceive of; see in one's mind
#
#   Sense 17: → EN: see, consider, reckon
#     Definition [en]: deem to be
#
#   Sense 18: → EN: perceive
#     Definition [en]: become conscious of
#
#   Sense 19: → EN: visit, see
#     Definition [en]: go to see a place, as for entertainment
#
#   Sense 20: → EN: greet, recognize, recognise
#     Definition [en]: express greetings upon meeting someone
#
#   Sense 21: → EN: follow
#     Definition [en]: to travel behind, go after, come after
#
#   Sense 22: → EN: take
#     Definition [en]: take into one's possession
#
#   Sense 23: → EN: understand, realize, realise
#     Definition [en]: perceive (an idea or situation) mentally
#
#   Sense 24: → EN: interpret, construe, see
#     Definition [en]: make sense of; assign a meaning to
#
#   Sense 25: → EN: remove, take, take away
#     Definition [en]: remove something concrete, as by lifting, pushing, or taking off, or remove...
#
#   Sense 26: → EN: acknowledge, recognize, recognise
#     Definition [en]: express obligation, thanks, or gratitude for
#
#   Sense 27: → EN: feel
#     Definition [en]: be felt or perceived in a certain way
#
#   Sense 28: → EN: understand
#     Definition [en]: know and comprehend the nature or meaning of
#
#   Sense 29: → EN: lead, take, direct
#     Definition [en]: take somebody somewhere
#
#   Sense 30: → EN: film, shoot, take
#     Definition [en]: make a film or photograph of something
#
#   Sense 31: → EN: succeed, come after, follow
#     Definition [en]: be the successor (of)
#
#   Sense 32: → EN: learn, study, read
#     Definition [en]: be a student of a certain subject
#
#   Sense 33: → EN: experience, see, go through
#     Definition [en]: go or live through
#
#   Sense 34: → EN: observe
#     Definition [en]: watch attentively
#
#   Sense 35: → EN: watch, observe, follow
#     Definition [en]: follow with the eyes or the mind
#
#   Sense 36: → EN: feel, sense
#     Definition [en]: perceive by a physical sensation, e.g., coming from the skin or muscles
#
#   Sense 37: → EN: adopt, follow, espouse
#     Definition [en]: choose and follow; as of theories, ideas, policies, strategies or plans
#
#   Sense 38: → EN: realize, realise, actualize
#     Definition [en]: make real or concrete; give reality or substance to
#
#   Sense 39: → EN: penetrate, perforate
#     Definition [en]: pass into or through, often by overcoming resistance
#
#   Sense 40: → EN: necessitate, ask, postulate
#     Definition [en]: require as useful, just, or proper
#
#   Sense 41: → EN: follow, conform to
#     Definition [en]: behave in accordance or in agreement with
#
#   Sense 42: → EN: feel, experience
#     Definition [en]: undergo an emotional sensation or be in a particular state of mind
#
#   Sense 43: → EN: perceive, comprehend
#     Definition [en]: to become aware of through the senses
#
#   Sense 44: → EN: overwhelm, overpower, sweep over
#     Definition [en]: overcome, as with emotions or perceptual stimuli
#
#   Sense 45: → EN: accept, admit, take
#     Definition [en]: admit into a group or community
#
#   Sense 46: → EN: pierce
#     Definition [en]: make a hole into
#
#   Sense 47: → EN: pursue, follow
#     Definition [en]: follow in or as if in pursuit
#
#   Sense 48: → EN: take
#     Definition [en]: take by force
#
# ======================================================================
# 📝 أثار (v) - 47 senses
# ======================================================================
#
#   Sense 1: → EN: irritate
#     Definition [en]: excite to an abnormal condition, or chafe or inflame
#
#   Sense 2: → EN: work, do work
#     Definition [en]: be employed
#
#   Sense 3: → EN: solve, work out, figure out
#     Definition [en]: find the solution to (a problem or question) or understand the meaning of
#
#   Sense 4: → EN: act, move
#     Definition [en]: perform an action, or work out or perform (an action)
#
#   Sense 5: → EN: annoy, rag, get to
#     Definition [en]: cause annoyance in; disturb, especially by minor irritations
#
#   Sense 6: → EN: suggest, evoke, paint a picture
#     Definition [en]: call to mind
#
#   Sense 7: → EN: suffer, sustain, have
#     Definition [en]: undergo (as of injuries and illnesses)
#
#   Sense 8: → EN: move, make a motion
#     Definition [en]: propose formally; in a debate or parliamentary meeting
#
#   Sense 9: → EN: transport, carry
#     Definition [en]: move while supporting, either in a vehicle or in one's hands or on one's bo...
#
#   Sense 10: → EN: stimulate, shake, shake up
#     Definition [en]: stir the feelings, emotions, or peace of
#
#   Sense 11: → EN: worsen, aggravate, exacerbate
#     Definition [en]: make worse
#
#   Sense 12: → EN: arouse, elicit, enkindle
#     Definition [en]: call forth (emotions, feelings, and responses)
#
#   Sense 13: → EN: work, put to work
#     Definition [en]: cause to work
#
#   Sense 14: → EN: move
#     Definition [en]: move so as to change position, perform a nontranslational motion
#
#   Sense 15: → EN: undergo
#     Definition [en]: pass through
#
#   Sense 16: → EN: inspire, animate, invigorate
#     Definition [en]: heighten or intensify
#
#   Sense 17: → EN: disturb, upset, trouble
#     Definition [en]: move deeply
#
#   Sense 18: → EN: transmit, transfer, transport
#     Definition [en]: send from one person or place to another
#
#   Sense 19: → EN: heat, heat up
#     Definition [en]: make hot or hotter
#
#   Sense 20: → EN: shape, form, work
#     Definition [en]: make something, usually for a specific function
#
#   Sense 21: → EN: get, acquire
#     Definition [en]: come into the possession of something concrete or abstract
#
#   Sense 22: → EN: influence, act upon, work
#     Definition [en]: have and exert influence or effect
#
#   Sense 23: → EN: arrive, get, come
#     Definition [en]: reach a destination; arrive by movement or progress
#
#   Sense 24: → EN: stimulate, arouse, brace
#     Definition [en]: cause to be alert and energetic
#
#   Sense 25: → EN: arouse, sex, excite
#     Definition [en]: stimulate sexually
#
#   Sense 26: → EN: travel, go, move
#     Definition [en]: change location; move, travel, or proceed, also metaphorically
#
#   Sense 27: → EN: stimulate, excite
#     Definition [en]: act as a stimulant
#
#   Sense 28: → EN: recommend, urge, advocate
#     Definition [en]: push for something
#
#   Sense 29: → EN: move, go
#     Definition [en]: have a turn; make one's move in a game
#
#   Sense 30: → EN: raise, conjure, conjure up
#     Definition [en]: summon into action or bring into existence, often as if by magic
#
#   Sense 31: → EN: burn, combust
#     Definition [en]: cause to burn or combust
#
#   Sense 32: → EN: grow, develop, produce
#     Definition [en]: come to have or undergo a change of (physical features and attributes)
#
#   Sense 33: → EN: wake up, awake, arouse
#     Definition [en]: stop sleeping
#
#   Sense 34: → EN: affect, impress, move
#     Definition [en]: have an emotional or cognitive impact upon
#
#   Sense 35: → EN: work
#     Definition [en]: exert oneself by doing mental or physical work for a purpose or out of nece...
#
#   Sense 36: → EN: move, displace
#     Definition [en]: cause to move or shift into a new position or place, both in a concrete and...
#
#   Sense 37: → EN: make, get
#     Definition [en]: give certain properties to something
#
#   Sense 38: → EN: exploit, work
#     Definition [en]: use or manipulate to one's advantage
#
#   Sense 39: → EN: enchant, enrapture, transport
#     Definition [en]: hold spellbound
#
#   Sense 40: → EN: bring, get, convey
#     Definition [en]: go or come after and bring or take back
#
#   Sense 41: → EN: urge, urge on, press
#     Definition [en]: force or impel in an indicated direction
#
#   Sense 42: → EN: work
#     Definition [en]: proceed towards a goal or along a path or through an activity
#
#   Sense 43: → EN: induce, stimulate, cause
#     Definition [en]: cause to do; cause to act in a specified manner
#
#   Sense 44: → EN: sour, turn, ferment
#     Definition [en]: go sour or spoil
#
#   Sense 45: → EN: get, catch, capture
#     Definition [en]: succeed in catching or seizing, especially after a chase
#
#   Sense 46: → EN: infuriate, exasperate, incense
#     Definition [en]: make furious
#
#   Sense 47: → EN: transport
#     Definition [en]: move something or somebody around; usually over long distances
#
# ======================================================================
# 📝 فصل (v) - 46 senses
# ======================================================================
#
#   Sense 1: → EN: arouse, elicit, enkindle
#     Definition [en]: call forth (emotions, feelings, and responses)
#
#   Sense 2: → EN: unwrap, disclose, let on
#     Definition [en]: make known to the public information that was previously known only to a fe...
#
#   Sense 3: → EN: expel, throw out, kick out
#     Definition [en]: force to leave or move out
#
#   Sense 4: → EN: estimate, gauge, approximate
#     Definition [en]: judge tentatively or form an estimate of (quantities or time)
#
#   Sense 5: → EN: separate
#     Definition [en]: divide into components or constituents
#
#   Sense 6: → EN: divide, split, split up
#     Definition [en]: separate into parts or portions
#
#   Sense 7: → EN: decide, settle, resolve
#     Definition [en]: bring to an end; settle conclusively
#
#   Sense 8: → EN: fire, discharge
#     Definition [en]: cause to go off
#
#   Sense 9: → EN: separate, divide
#     Definition [en]: make a division or separation
#
#   Sense 10: → EN: ignore, disregard, snub
#     Definition [en]: refuse to acknowledge
#
#   Sense 11: → EN: sink, settle, go down
#     Definition [en]: go under
#
#   Sense 12: → EN: classify, class, sort
#     Definition [en]: arrange or order by classes or categories
#
#   Sense 13: → EN: discharge
#     Definition [en]: pour forth or release
#
#   Sense 14: → EN: separate, part, split up
#     Definition [en]: discontinue an association or relation; go different ways
#
#   Sense 15: → EN: remove, take, take away
#     Definition [en]: remove something concrete, as by lifting, pushing, or taking off, or remove...
#
#   Sense 16: → EN: reduce, cut down, cut back
#     Definition [en]: cut down on; make a reduction in
#
#   Sense 17: → EN: determine, find, find out
#     Definition [en]: establish after a calculation, investigation, experiment, survey, or study
#
#   Sense 18: → EN: reconcile, patch up, make up
#     Definition [en]: come to terms
#
#   Sense 19: → EN: abridge, foreshorten, abbreviate
#     Definition [en]: reduce in scope while retaining essential elements
#
#   Sense 20: → EN: pronounce, label, judge
#     Definition [en]: pronounce judgment on
#
#   Sense 21: → EN: get rid of, remove
#     Definition [en]: dispose of
#
#   Sense 22: → EN: separate, part, split
#     Definition [en]: go one's own way; move apart
#
#   Sense 23: → EN: remove
#     Definition [en]: remove from a position or an office
#
#   Sense 24: → EN: displace, fire, give notice
#     Definition [en]: terminate the employment of; discharge from an office or position
#
#   Sense 25: → EN: dislocate
#     Definition [en]: put out of its usual place, position, or relationship
#
#   Sense 26: → EN: distinguish, separate, differentiate
#     Definition [en]: mark as different
#
#   Sense 27: → EN: divide, fraction
#     Definition [en]: perform a division
#
#   Sense 28: → EN: separate, divide, part
#     Definition [en]: come apart
#
#   Sense 29: → EN: settle, settle down
#     Definition [en]: settle into a position, usually on a surface or ground
#
#   Sense 30: → EN: settle
#     Definition [en]: end a legal dispute by arriving at a settlement
#
#   Sense 31: → EN: decide, make up one's mind, determine
#     Definition [en]: reach, make, or come to a decision about something
#
#   Sense 32: → EN: separate, disunite, divide
#     Definition [en]: force, take, or pull apart
#
#   Sense 33: → EN: break
#     Definition [en]: destroy the integrity of; usually by force; cause to separate into pieces o...
#
#   Sense 34: → EN: evaluate, pass judgment, judge
#     Definition [en]: form a critical opinion of
#
#   Sense 35: → EN: move, displace
#     Definition [en]: cause to move or shift into a new position or place, both in a concrete and...
#
#   Sense 36: → EN: eject, chuck out, exclude
#     Definition [en]: put out or expel from a place
#
#   Sense 37: → EN: disconnect
#     Definition [en]: make disconnected, disjoin or unfasten
#
#   Sense 38: → EN: judge
#     Definition [en]: determine the result of (a competition)
#
#   Sense 39: → EN: ensconce, settle
#     Definition [en]: fix firmly
#
#   Sense 40: → EN: detach, come off, come away
#     Definition [en]: come to be detached
#
#   Sense 41: → EN: break, bust
#     Definition [en]: ruin completely
#
#   Sense 42: → EN: cut
#     Definition [en]: separate with or as if with an instrument
#
#   Sense 43: → EN: separate, divide
#     Definition [en]: act as a barrier between; stand between
#
#   Sense 44: → EN: break, separate, split up
#     Definition [en]: become separated into pieces or fragments
#
#   Sense 45: → EN: fire, discharge, go off
#     Definition [en]: go off or discharge
#
#   Sense 46: → EN: exhaust, discharge, expel
#     Definition [en]: eliminate (a substance)
#
# ======================================================================
# 📝 حمل (v) - 45 senses
# ======================================================================
#
#   Sense 1: → EN: continue, go on, carry on
#     Definition [en]: continue talking
#
#   Sense 2: → EN: appoint, charge
#     Definition [en]: assign a duty, responsibility or obligation to
#
#   Sense 3: → EN: carry, convey, express
#     Definition [en]: serve as a means for expressing something
#
#   Sense 4: → EN: hold
#     Definition [en]: hold the attention of
#
#   Sense 5: → EN: campaign, take the field
#     Definition [en]: go on a campaign; go off to war
#
#   Sense 6: → EN: bear, hold
#     Definition [en]: have rightfully; of rights, titles, and offices
#
#   Sense 7: → EN: take, read
#     Definition [en]: interpret something in a certain way; convey a particular meaning or impres...
#
#   Sense 8: → EN: have a bun in the oven, bear, carry
#     Definition [en]: be pregnant with
#
#   Sense 9: → EN: necessitate, ask, postulate
#     Definition [en]: require as useful, just, or proper
#
#   Sense 10: → EN: take
#     Definition [en]: take into one's possession
#
#   Sense 11: → EN: choose, take, select
#     Definition [en]: pick out, select, or choose from a number of alternatives
#
#   Sense 12: → EN: bring, convey, take
#     Definition [en]: take something or somebody with oneself somewhere
#
#   Sense 13: → EN: bear, turn out
#     Definition [en]: bring forth
#
#   Sense 14: → EN: remove, take, take away
#     Definition [en]: remove something concrete, as by lifting, pushing, or taking off, or remove...
#
#   Sense 15: → EN: charge, bill
#     Definition [en]: demand payment
#
#   Sense 16: → EN: conduct, carry on, deal
#     Definition [en]: direct the course of; manage or control
#
#   Sense 17: → EN: hold, carry, bear
#     Definition [en]: support or hold in a certain manner
#
#   Sense 18: → EN: deem, hold, view as
#     Definition [en]: keep in mind or convey as a conviction or view
#
#   Sense 19: → EN: control, hold in, hold
#     Definition [en]: lessen the intensity of; temper; hold in restraint; hold or keep within lim...
#
#   Sense 20: → EN: charge
#     Definition [en]: fill or load to capacity
#
#   Sense 21: → EN: raise, lift, elevate
#     Definition [en]: raise from a lower to a higher position
#
#   Sense 22: → EN: bear
#     Definition [en]: move while holding up or supporting
#
#   Sense 23: → EN: lead, take, direct
#     Definition [en]: take somebody somewhere
#
#   Sense 24: → EN: keep, maintain, hold
#     Definition [en]: keep in a certain state, position, or activity; e.g.
#
#   Sense 25: → EN: charge, accuse
#     Definition [en]: blame for, make a claim of wrongdoing or misbehavior against
#
#   Sense 26: → EN: learn, study, read
#     Definition [en]: be a student of a certain subject
#
#   Sense 27: → EN: have, have got, hold
#     Definition [en]: have or possess, either in a concrete or an abstract sense
#
#   Sense 28: → EN: take
#     Definition [en]: take by force
#
#   Sense 29: → EN: film, shoot, take
#     Definition [en]: make a film or photograph of something
#
#   Sense 30: → EN: accept, take, have
#     Definition [en]: receive willingly something given or offered
#
#   Sense 31: → EN: hold, bear, carry
#     Definition [en]: contain or hold; have within
#
#   Sense 32: → EN: charge
#     Definition [en]: cause formation of a net electrical charge in or on
#
#   Sense 33: → EN: commit, institutionalize, institutionalise
#     Definition [en]: cause to be admitted; of persons to an institution
#
#   Sense 34: → EN: accept, admit, take
#     Definition [en]: admit into a group or community
#
#   Sense 35: → EN: restrain, confine, hold
#     Definition [en]: to close within bounds, limit or hold back from movement
#
#   Sense 36: → EN: agree, hold, concur
#     Definition [en]: be in accord; be in agreement
#
#   Sense 37: → EN: refer, pertain, relate
#     Definition [en]: be relevant to
#
#   Sense 38: → EN: transport, carry
#     Definition [en]: move while supporting, either in a vehicle or in one's hands or on one's bo...
#
#   Sense 39: → EN: carry, pack, take
#     Definition [en]: have with oneself; have on one's person
#
#   Sense 40: → EN: hold
#     Definition [en]: keep from exhaling or expelling
#
#   Sense 41: → EN: behave, acquit, bear
#     Definition [en]: behave in a certain manner
#
#   Sense 42: → EN: hold, take hold
#     Definition [en]: have or hold in one's hands or grip
#
#   Sense 43: → EN: load, lade, laden
#     Definition [en]: fill or place a load on
#
#   Sense 44: → EN: declare, adjudge, hold
#     Definition [en]: declare to be
#
#   Sense 45: → EN: continue, uphold, carry on
#     Definition [en]: keep or maintain in unaltered condition; cause to remain or last
#
# ======================================================================
# 📝 حقق (v) - 45 senses
# ======================================================================
#
#   Sense 1: → EN: reach, hit, attain
#     Definition [en]: reach a point in time, or a certain state or level
#
#   Sense 2: → EN: necessitate, ask, postulate
#     Definition [en]: require as useful, just, or proper
#
#   Sense 3: → EN: remove, take, take away
#     Definition [en]: remove something concrete, as by lifting, pushing, or taking off, or remove...
#
#   Sense 4: → EN: visualize, visualise, envision
#     Definition [en]: imagine; conceive of; see in one's mind
#
#   Sense 5: → EN: carry through, accomplish, execute
#     Definition [en]: put in effect
#
#   Sense 6: → EN: examine, see
#     Definition [en]: observe, check out, and look over carefully or inspect
#
#   Sense 7: → EN: film, shoot, take
#     Definition [en]: make a film or photograph of something
#
#   Sense 8: → EN: achieve, accomplish, attain
#     Definition [en]: to gain with effort
#
#   Sense 9: → EN: see, consider, reckon
#     Definition [en]: deem to be
#
#   Sense 10: → EN: reach, make, attain
#     Definition [en]: reach a destination, either real or abstract
#
#   Sense 11: → EN: take
#     Definition [en]: take by force
#
#   Sense 12: → EN: visit, see
#     Definition [en]: go to see a place, as for entertainment
#
#   Sense 13: → EN: determine, check, find out
#     Definition [en]: find out, learn, or determine with certainty, usually by making an inquiry ...
#
#   Sense 14: → EN: experience, see, go through
#     Definition [en]: go or live through
#
#   Sense 15: → EN: produce, bring forth
#     Definition [en]: bring out for display
#
#   Sense 16: → EN: realize, realise, actualize
#     Definition [en]: make real or concrete; give reality or substance to
#
#   Sense 17: → EN: lead, take, direct
#     Definition [en]: take somebody somewhere
#
#   Sense 18: → EN: match, fit, correspond
#     Definition [en]: be compatible, similar or consistent; coincide in their characteristics
#
#   Sense 19: → EN: respect, esteem, value
#     Definition [en]: regard highly; think much of
#
#   Sense 20: → EN: meet, run into, encounter
#     Definition [en]: come together
#
#   Sense 21: → EN: understand, realize, realise
#     Definition [en]: perceive (an idea or situation) mentally
#
#   Sense 22: → EN: satisfy, fulfill, fulfil
#     Definition [en]: meet the requirements or expectations of
#
#   Sense 23: → EN: produce, bring forth
#     Definition [en]: bring forth or yield
#
#   Sense 24: → EN: meet, satisfy, fill
#     Definition [en]: fill or meet a want or need
#
#   Sense 25: → EN: interpret, construe, see
#     Definition [en]: make sense of; assign a meaning to
#
#   Sense 26: → EN: accept, admit, take
#     Definition [en]: admit into a group or community
#
#   Sense 27: → EN: check, check up on, look into
#     Definition [en]: examine so as to determine accuracy, quality, or condition
#
#   Sense 28: → EN: produce, make, create
#     Definition [en]: create or manufacture a man-made product
#
#   Sense 29: → EN: see
#     Definition [en]: perceive by sight or have the power to perceive by sight
#
#   Sense 30: → EN: choose, take, select
#     Definition [en]: pick out, select, or choose from a number of alternatives
#
#   Sense 31: → EN: take, read
#     Definition [en]: interpret something in a certain way; convey a particular meaning or impres...
#
#   Sense 32: → EN: learn, study, read
#     Definition [en]: be a student of a certain subject
#
#   Sense 33: → EN: determine, find, find out
#     Definition [en]: establish after a calculation, investigation, experiment, survey, or study
#
#   Sense 34: → EN: probe, examine
#     Definition [en]: question or examine thoroughly and closely
#
#   Sense 35: → EN: learn, hear, get word
#     Definition [en]: get to know or become aware of, usually accidentally
#
#   Sense 36: → EN: grow, develop, produce
#     Definition [en]: come to have or undergo a change of (physical features and attributes)
#
#   Sense 37: → EN: prize, value, treasure
#     Definition [en]: hold dear
#
#   Sense 38: → EN: investigate, inquire, enquire
#     Definition [en]: conduct an inquiry or investigation of
#
#   Sense 39: → EN: take
#     Definition [en]: take into one's possession
#
#   Sense 40: → EN: bring, convey, take
#     Definition [en]: take something or somebody with oneself somewhere
#
#   Sense 41: → EN: control, hold in, hold
#     Definition [en]: lessen the intensity of; temper; hold in restraint; hold or keep within lim...
#
#   Sense 42: → EN: happen, materialize, materialise
#     Definition [en]: come into being; become reality
#
#   Sense 43: → EN: effect, effectuate, set up
#     Definition [en]: produce
#
#   Sense 44: → EN: accept, take, have
#     Definition [en]: receive willingly something given or offered
#
#   Sense 45: → EN: ascertain
#     Definition [en]: learn or discover with certainty
#
# ======================================================================
# 📝 رافق (v) - 44 senses
# ======================================================================
#
#   Sense 1: → EN: visualize, visualise, envision
#     Definition [en]: imagine; conceive of; see in one's mind
#
#   Sense 2: → EN: accompany
#     Definition [en]: go or travel along with
#
#   Sense 3: → EN: transport, carry
#     Definition [en]: move while supporting, either in a vehicle or in one's hands or on one's bo...
#
#   Sense 4: → EN: join, fall in, get together
#     Definition [en]: become part of; become a member of a group or organization
#
#   Sense 5: → EN: see
#     Definition [en]: perceive by sight or have the power to perceive by sight
#
#   Sense 6: → EN: hold, carry, bear
#     Definition [en]: support or hold in a certain manner
#
#   Sense 7: → EN: learn, study, read
#     Definition [en]: be a student of a certain subject
#
#   Sense 8: → EN: carry, pack, take
#     Definition [en]: have with oneself; have on one's person
#
#   Sense 9: → EN: join, bring together
#     Definition [en]: cause to become joined or linked
#
#   Sense 10: → EN: follow
#     Definition [en]: to travel behind, go after, come after
#
#   Sense 11: → EN: film, shoot, take
#     Definition [en]: make a film or photograph of something
#
#   Sense 12: → EN: lead, take, direct
#     Definition [en]: take somebody somewhere
#
#   Sense 13: → EN: visit, see
#     Definition [en]: go to see a place, as for entertainment
#
#   Sense 14: → EN: accept, take, have
#     Definition [en]: receive willingly something given or offered
#
#   Sense 15: → EN: examine, see
#     Definition [en]: observe, check out, and look over carefully or inspect
#
#   Sense 16: → EN: join, conjoin
#     Definition [en]: make contact or come together
#
#   Sense 17: → EN: meet, run into, encounter
#     Definition [en]: come together
#
#   Sense 18: → EN: company, companion, accompany
#     Definition [en]: be a companion to somebody
#
#   Sense 19: → EN: attach to, accompany, come with
#     Definition [en]: be present or associated with an event or entity
#
#   Sense 20: → EN: walk
#     Definition [en]: accompany or escort
#
#   Sense 21: → EN: see, consider, reckon
#     Definition [en]: deem to be
#
#   Sense 22: → EN: follow, fall out
#     Definition [en]: come as a logical consequence; follow logically
#
#   Sense 23: → EN: necessitate, ask, postulate
#     Definition [en]: require as useful, just, or proper
#
#   Sense 24: → EN: take, read
#     Definition [en]: interpret something in a certain way; convey a particular meaning or impres...
#
#   Sense 25: → EN: lend, impart, bestow
#     Definition [en]: bestow a quality on
#
#   Sense 26: → EN: succeed, come after, follow
#     Definition [en]: be the successor (of)
#
#   Sense 27: → EN: remove, take, take away
#     Definition [en]: remove something concrete, as by lifting, pushing, or taking off, or remove...
#
#   Sense 28: → EN: take
#     Definition [en]: take by force
#
#   Sense 29: → EN: interpret, construe, see
#     Definition [en]: make sense of; assign a meaning to
#
#   Sense 30: → EN: behave, acquit, bear
#     Definition [en]: behave in a certain manner
#
#   Sense 31: → EN: learn, hear, get word
#     Definition [en]: get to know or become aware of, usually accidentally
#
#   Sense 32: → EN: pursue, follow
#     Definition [en]: follow in or as if in pursuit
#
#   Sense 33: → EN: have a bun in the oven, bear, carry
#     Definition [en]: be pregnant with
#
#   Sense 34: → EN: follow, conform to
#     Definition [en]: behave in accordance or in agreement with
#
#   Sense 35: → EN: bring, land
#     Definition [en]: bring into a different state
#
#   Sense 36: → EN: bring, get, convey
#     Definition [en]: go or come after and bring or take back
#
#   Sense 37: → EN: choose, take, select
#     Definition [en]: pick out, select, or choose from a number of alternatives
#
#   Sense 38: → EN: accept, admit, take
#     Definition [en]: admit into a group or community
#
#   Sense 39: → EN: hold, bear, carry
#     Definition [en]: contain or hold; have within
#
#   Sense 40: → EN: bring, convey, take
#     Definition [en]: take something or somebody with oneself somewhere
#
#   Sense 41: → EN: take
#     Definition [en]: take into one's possession
#
#   Sense 42: → EN: experience, see, go through
#     Definition [en]: go or live through
#
#   Sense 43: → EN: inhere in, attach to
#     Definition [en]: be part of
#
#   Sense 44: → EN: adopt, follow, espouse
#     Definition [en]: choose and follow; as of theories, ideas, policies, strategies or plans
#
# ======================================================================
# 📝 حول (v) - 43 senses
# ======================================================================
#
#   Sense 1: → EN: exploit, work
#     Definition [en]: use or manipulate to one's advantage
#
#   Sense 2: → EN: deliver
#     Definition [en]: bring to a destination, make a delivery
#
#   Sense 3: → EN: refer, pertain, relate
#     Definition [en]: be relevant to
#
#   Sense 4: → EN: work, put to work
#     Definition [en]: cause to work
#
#   Sense 5: → EN: discontinue, stop, cease
#     Definition [en]: put an end to a state or an activity
#
#   Sense 6: → EN: make, get
#     Definition [en]: give certain properties to something
#
#   Sense 7: → EN: give, dedicate, consecrate
#     Definition [en]: give entirely to a specific person, activity, or cause
#
#   Sense 8: → EN: give birth, deliver, bear
#     Definition [en]: cause to be born
#
#   Sense 9: → EN: create, make
#     Definition [en]: create by artistic means
#
#   Sense 10: → EN: make, create
#     Definition [en]: make or cause to be or to become
#
#   Sense 11: → EN: shape, form, work
#     Definition [en]: make something, usually for a specific function
#
#   Sense 12: → EN: transform, transmute, transubstantiate
#     Definition [en]: change or alter in form, appearance, or nature
#
#   Sense 13: → EN: induce, stimulate, cause
#     Definition [en]: cause to do; cause to act in a specified manner
#
#   Sense 14: → EN: withdraw, retreat, pull away
#     Definition [en]: pull back or move away or backward
#
#   Sense 15: → EN: work, do work
#     Definition [en]: be employed
#
#   Sense 16: → EN: change state, turn
#     Definition [en]: undergo a transformation or a change of position or action
#
#   Sense 17: → EN: commit, institutionalize, institutionalise
#     Definition [en]: cause to be admitted; of persons to an institution
#
#   Sense 18: → EN: refer
#     Definition [en]: think of, regard, or classify under a subsuming principle or with a general...
#
#   Sense 19: → EN: cause, do, make
#     Definition [en]: give rise to; cause to happen or occur, not always intentionally
#
#   Sense 20: → EN: work
#     Definition [en]: exert oneself by doing mental or physical work for a purpose or out of nece...
#
#   Sense 21: → EN: remove, take, take away
#     Definition [en]: remove something concrete, as by lifting, pushing, or taking off, or remove...
#
#   Sense 22: → EN: work
#     Definition [en]: proceed towards a goal or along a path or through an activity
#
#   Sense 23: → EN: cook, fix, ready
#     Definition [en]: prepare for eating by applying heat
#
#   Sense 24: → EN: surrender, cede, deliver
#     Definition [en]: relinquish possession or control over
#
#   Sense 25: → EN: solve, work out, figure out
#     Definition [en]: find the solution to (a problem or question) or understand the meaning of
#
#   Sense 26: → EN: switch, shift, change
#     Definition [en]: lay aside, abandon, or leave for another
#
#   Sense 27: → EN: turn
#     Definition [en]: move around an axis or a center
#
#   Sense 28: → EN: denote, refer
#     Definition [en]: have as a meaning
#
#   Sense 29: → EN: influence, act upon, work
#     Definition [en]: have and exert influence or effect
#
#   Sense 30: → EN: transform, transmute, metamorphose
#     Definition [en]: change in outward structure or looks
#
#   Sense 31: → EN: barricade, block, blockade
#     Definition [en]: render unsuitable for passage
#
#   Sense 32: → EN: transmit, transfer, transport
#     Definition [en]: send from one person or place to another
#
#   Sense 33: → EN: turn
#     Definition [en]: change orientation or direction, also in the abstract sense
#
#   Sense 34: → EN: construct, build, make
#     Definition [en]: make by combining materials and parts
#
#   Sense 35: → EN: rescue, deliver
#     Definition [en]: free from harm or evil
#
#   Sense 36: → EN: reach, make, attain
#     Definition [en]: reach a destination, either real or abstract
#
#   Sense 37: → EN: make
#     Definition [en]: form by assembling individuals or constituents
#
#   Sense 38: → EN: produce, make, create
#     Definition [en]: create or manufacture a man-made product
#
#   Sense 39: → EN: transfer
#     Definition [en]: move from one place to another
#
#   Sense 40: → EN: sour, turn, ferment
#     Definition [en]: go sour or spoil
#
#   Sense 41: → EN: lay down, establish, make
#     Definition [en]: institute, enact, or establish
#
#   Sense 42: → EN: change by reversal, turn, reverse
#     Definition [en]: change to the contrary
#
#   Sense 43: → EN: end, stop, finish
#     Definition [en]: have an end, in a temporal, spatial, or quantitative sense; either spatial ...
#
# ======================================================================
# 📝 نشر (v) - 42 senses
# ======================================================================
#
#   Sense 1: → EN: publish, bring out, put out
#     Definition [en]: prepare and issue for public distribution or sale
#
#   Sense 2: → EN: run, go, pass
#     Definition [en]: stretch out over a distance, space, time, or scope; run or extend between t...
#
#   Sense 3: → EN: print, publish
#     Definition [en]: put into print
#
#   Sense 4: → EN: melt, run, melt down
#     Definition [en]: reduce or cause to be reduced from a solid to a liquid state, usually by he...
#
#   Sense 5: → EN: publicize, publicise, air
#     Definition [en]: make public
#
#   Sense 6: → EN: use, utilize, utilise
#     Definition [en]: put into service; make work or employ for a particular purpose or for its i...
#
#   Sense 7: → EN: unwrap, disclose, let on
#     Definition [en]: make known to the public information that was previously known only to a fe...
#
#   Sense 8: → EN: dispose, incline
#     Definition [en]: make receptive or willing towards an action or attitude or belief
#
#   Sense 9: → EN: give birth, deliver, bear
#     Definition [en]: cause to be born
#
#   Sense 10: → EN: run, flow, feed
#     Definition [en]: move along, of liquids
#
#   Sense 11: → EN: stretch, extend
#     Definition [en]: extend one's limbs or muscles, or the entire body
#
#   Sense 12: → EN: advertise, publicize, advertize
#     Definition [en]: call attention to
#
#   Sense 13: → EN: distribute, administer, mete out
#     Definition [en]: administer or bestow, as in small portions
#
#   Sense 14: → EN: expand
#     Definition [en]: become larger in size or volume or quantity
#
#   Sense 15: → EN: unfold, spread, spread out
#     Definition [en]: spread out or open from a closed or folded state
#
#   Sense 16: → EN: go around, spread, circulate
#     Definition [en]: become widely known and passed on
#
#   Sense 17: → EN: bear
#     Definition [en]: move while holding up or supporting
#
#   Sense 18: → EN: out, come out
#     Definition [en]: be made known; be disclosed or revealed
#
#   Sense 19: → EN: spread, overspread
#     Definition [en]: spread across or over
#
#   Sense 20: → EN: thrust
#     Definition [en]: push forcefully
#
#   Sense 21: → EN: deploy
#     Definition [en]: place troops or weapons in battle formation
#
#   Sense 22: → EN: put on, apply
#     Definition [en]: apply to a surface
#
#   Sense 23: → EN: hold, carry, bear
#     Definition [en]: support or hold in a certain manner
#
#   Sense 24: → EN: have a bun in the oven, bear, carry
#     Definition [en]: be pregnant with
#
#   Sense 25: → EN: grind, mash, crunch
#     Definition [en]: reduce to small pieces or particles by pounding or abrading
#
#   Sense 26: → EN: behave, acquit, bear
#     Definition [en]: behave in a certain manner
#
#   Sense 27: → EN: circulate, pass around, pass on
#     Definition [en]: cause be distributed
#
#   Sense 28: → EN: scatter, sprinkle, dot
#     Definition [en]: distribute loosely
#
#   Sense 29: → EN: scat, run, scarper
#     Definition [en]: flee; take to one's heels; cut and run
#
#   Sense 30: → EN: digest, endure, stick out
#     Definition [en]: put up with something or somebody unpleasant
#
#   Sense 31: → EN: hold, bear, carry
#     Definition [en]: contain or hold; have within
#
#   Sense 32: → EN: cover, continue, extend
#     Definition [en]: span an interval of distance, space or time
#
#   Sense 33: → EN: diffuse, spread, spread out
#     Definition [en]: move outward
#
#   Sense 34: → EN: spread, distribute
#     Definition [en]: distribute or disperse widely
#
#   Sense 35: → EN: bear, turn out
#     Definition [en]: bring forth
#
#   Sense 36: → EN: spread, scatter, spread out
#     Definition [en]: strew or distribute over an area
#
#   Sense 37: → EN: unfold, stretch, stretch out
#     Definition [en]: extend or stretch out to a greater or the full length
#
#   Sense 38: → EN: sow, seed
#     Definition [en]: place (seeds) in or on the ground for future growth
#
#   Sense 39: → EN: bear, hold
#     Definition [en]: have rightfully; of rights, titles, and offices
#
#   Sense 40: → EN: saw
#     Definition [en]: cut with a saw
#
#   Sense 41: → EN: yield, pay, bear
#     Definition [en]: bring in
#
#   Sense 42: → EN: run
#     Definition [en]: move fast by using one's feet, with one foot off the ground at any given ti...
#
# ======================================================================
# 📝 حدث (v) - 41 senses
# ======================================================================
#
#   Sense 1: → EN: flow, flux
#     Definition [en]: move or progress freely as if in a stream
#
#   Sense 2: → EN: elapse, lapse, pass
#     Definition [en]: pass by
#
#   Sense 3: → EN: die, decease, perish
#     Definition [en]: pass from physical life and lose all bodily attributes and functions necess...
#
#   Sense 4: → EN: proceed, go
#     Definition [en]: follow a certain course
#
#   Sense 5: → EN: evanesce, fade, blow over
#     Definition [en]: disappear gradually
#
#   Sense 6: → EN: rise, come up, uprise
#     Definition [en]: come up, of celestial bodies
#
#   Sense 7: → EN: sound, go
#     Definition [en]: make a certain noise or sound
#
#   Sense 8: → EN: exploit, work
#     Definition [en]: use or manipulate to one's advantage
#
#   Sense 9: → EN: function, work, operate
#     Definition [en]: perform as expected when applied
#
#   Sense 10: → EN: run, flow, feed
#     Definition [en]: move along, of liquids
#
#   Sense 11: → EN: rise, lift, arise
#     Definition [en]: move upward
#
#   Sense 12: → EN: rate, rank, range
#     Definition [en]: assign a rank or rating to
#
#   Sense 13: → EN: run, go, pass
#     Definition [en]: stretch out over a distance, space, time, or scope; run or extend between t...
#
#   Sense 14: → EN: travel by, pass by, surpass
#     Definition [en]: move past
#
#   Sense 15: → EN: total, number, add up
#     Definition [en]: add up in number or quantity
#
#   Sense 16: → EN: pass, hand, reach
#     Definition [en]: place into the hands or custody of
#
#   Sense 17: → EN: communicate, pass on, pass
#     Definition [en]: transmit information
#
#   Sense 18: → EN: happen, materialize, materialise
#     Definition [en]: come into being; become reality
#
#   Sense 19: → EN: station, post, send
#     Definition [en]: assign to a station
#
#   Sense 20: → EN: authorize, authorise, pass
#     Definition [en]: grant authorization or clearance for
#
#   Sense 21: → EN: occur, come
#     Definition [en]: come to one's mind; suggest itself
#
#   Sense 22: → EN: come, come up
#     Definition [en]: move toward, travel toward something or somebody or approach something or s...
#
#   Sense 23: → EN: happen, hap, go on
#     Definition [en]: come to pass
#
#   Sense 24: → EN: work, put to work
#     Definition [en]: cause to work
#
#   Sense 25: → EN: happen, befall, bechance
#     Definition [en]: happen, occur, or be the case in the course of events or by chance
#
#   Sense 26: → EN: occur
#     Definition [en]: to be found to exist
#
#   Sense 27: → EN: work
#     Definition [en]: proceed towards a goal or along a path or through an activity
#
#   Sense 28: → EN: solve, work out, figure out
#     Definition [en]: find the solution to (a problem or question) or understand the meaning of
#
#   Sense 29: → EN: rise, lift, rear
#     Definition [en]: rise up
#
#   Sense 30: → EN: identify, place
#     Definition [en]: recognize as being; establish the identity of someone or something
#
#   Sense 31: → EN: spend, pass
#     Definition [en]: pass time in a specific way
#
#   Sense 32: → EN: move, go
#     Definition [en]: have a turn; make one's move in a game
#
#   Sense 33: → EN: work, do work
#     Definition [en]: be employed
#
#   Sense 34: → EN: travel, go, move
#     Definition [en]: change location; move, travel, or proceed, also metaphorically
#
#   Sense 35: → EN: work
#     Definition [en]: exert oneself by doing mental or physical work for a purpose or out of nece...
#
#   Sense 36: → EN: arrive, get, come
#     Definition [en]: reach a destination; arrive by movement or progress
#
#   Sense 37: → EN: pass, go through, go across
#     Definition [en]: go across or through
#
#   Sense 38: → EN: put, set, place
#     Definition [en]: put into a certain place or abstract location
#
#   Sense 39: → EN: influence, act upon, work
#     Definition [en]: have and exert influence or effect
#
#   Sense 40: → EN: pass, make pass
#     Definition [en]: cause to pass
#
#   Sense 41: → EN: shape, form, work
#     Definition [en]: make something, usually for a specific function
#
# ======================================================================
# 📝 ظهر (v) - 41 senses
# ======================================================================
#
#   Sense 1: → EN: produce, make, create
#     Definition [en]: create or manufacture a man-made product
#
#   Sense 2: → EN: look, appear, seem
#     Definition [en]: give a certain impression or have a certain outward aspect
#
#   Sense 3: → EN: produce, bring forth
#     Definition [en]: bring out for display
#
#   Sense 4: → EN: grow, develop, produce
#     Definition [en]: come to have or undergo a change of (physical features and attributes)
#
#   Sense 5: → EN: appear
#     Definition [en]: come into sight or view
#
#   Sense 6: → EN: walk
#     Definition [en]: use one's feet to advance; advance by steps
#
#   Sense 7: → EN: bespeak, betoken, indicate
#     Definition [en]: be a signal for or a symptom of
#
#   Sense 8: → EN: develop, make grow
#     Definition [en]: cause to grow and differentiate in ways conforming to its natural developme...
#
#   Sense 9: → EN: notice, mark, note
#     Definition [en]: notice or perceive
#
#   Sense 10: → EN: coat, surface
#     Definition [en]: put a coat on; cover the surface of; furnish with a surface
#
#   Sense 11: → EN: exert, exercise
#     Definition [en]: put to use
#
#   Sense 12: → EN: surface, come up, rise up
#     Definition [en]: come to the surface
#
#   Sense 13: → EN: unwrap, disclose, let on
#     Definition [en]: make known to the public information that was previously known only to a fe...
#
#   Sense 14: → EN: rise, lift, arise
#     Definition [en]: move upward
#
#   Sense 15: → EN: mark
#     Definition [en]: make or leave a mark on
#
#   Sense 16: → EN: walk, take the air
#     Definition [en]: take a walk; go for a walk; walk for pleasure
#
#   Sense 17: → EN: discharge, muster out
#     Definition [en]: release from military service
#
#   Sense 18: → EN: prove, demonstrate, establish
#     Definition [en]: establish the validity of something, as by an example, explanation or exper...
#
#   Sense 19: → EN: uncover, bring out, unveil
#     Definition [en]: make visible
#
#   Sense 20: → EN: show
#     Definition [en]: make visible or noticeable
#
#   Sense 21: → EN: prove, turn out, turn up
#     Definition [en]: be shown or be found to be
#
#   Sense 22: → EN: expose, exhibit, display
#     Definition [en]: to show, make visible or apparent
#
#   Sense 23: → EN: happen, hap, go on
#     Definition [en]: come to pass
#
#   Sense 24: → EN: appear, come along
#     Definition [en]: come into being or existence, or appear on the scene
#
#   Sense 25: → EN: issue, emerge, come out
#     Definition [en]: come out of
#
#   Sense 26: → EN: emerge
#     Definition [en]: come out into view, as from concealment
#
#   Sense 27: → EN: come on, come out, turn up
#     Definition [en]: appear or become visible; make a showing
#
#   Sense 28: → EN: develop
#     Definition [en]: make visible by means of chemical solutions
#
#   Sense 29: → EN: jump, leap, bound
#     Definition [en]: move forward by leaps and bounds
#
#   Sense 30: → EN: out, come out
#     Definition [en]: be made known; be disclosed or revealed
#
#   Sense 31: → EN: declare, adjudge, hold
#     Definition [en]: declare to be
#
#   Sense 32: → EN: drill, exercise, practice
#     Definition [en]: learn by repetition
#
#   Sense 33: → EN: progress, come on, come along
#     Definition [en]: develop in a positive way
#
#   Sense 34: → EN: denote, refer
#     Definition [en]: have as a meaning
#
#   Sense 35: → EN: develop
#     Definition [en]: grow, progress, unfold, or evolve through a process of evolution, natural g...
#
#   Sense 36: → EN: testify, bear witness, prove
#     Definition [en]: provide evidence for
#
#   Sense 37: → EN: look
#     Definition [en]: have a certain outward or facial expression
#
#   Sense 38: → EN: show, demo, exhibit
#     Definition [en]: give an exhibition of to an interested audience
#
#   Sense 39: → EN: declare
#     Definition [en]: state emphatically and authoritatively
#
#   Sense 40: → EN: produce, bring forth
#     Definition [en]: bring forth or yield
#
#   Sense 41: → EN: announce, denote
#     Definition [en]: make known; make an announcement
#
# ======================================================================
# 📝 ترك (v) - 41 senses
# ======================================================================
#
#   Sense 1: → EN: separate, part, split up
#     Definition [en]: discontinue an association or relation; go different ways
#
#   Sense 2: → EN: leave, leave behind
#     Definition [en]: be survived by after one's death
#
#   Sense 3: → EN: drop
#     Definition [en]: go down in value
#
#   Sense 4: → EN: break, bust
#     Definition [en]: ruin completely
#
#   Sense 5: → EN: entrust, leave
#     Definition [en]: put into the care or protection of someone
#
#   Sense 6: → EN: digest, endure, stick out
#     Definition [en]: put up with something or somebody unpleasant
#
#   Sense 7: → EN: unwrap, disclose, let on
#     Definition [en]: make known to the public information that was previously known only to a fe...
#
#   Sense 8: → EN: leave behind
#     Definition [en]: depart and not take along
#
#   Sense 9: → EN: leave office, quit, step down
#     Definition [en]: give up or retire from a position
#
#   Sense 10: → EN: abandon, give up
#     Definition [en]: give up with the intent of never claiming again
#
#   Sense 11: → EN: leave, depart, pull up stakes
#     Definition [en]: remove oneself from an association with or participation in
#
#   Sense 12: → EN: abstain, refrain, desist
#     Definition [en]: choose not to consume
#
#   Sense 13: → EN: spend, expend, drop
#     Definition [en]: pay out
#
#   Sense 14: → EN: abandon, give up
#     Definition [en]: stop maintaining or insisting on; of ideas or claims
#
#   Sense 15: → EN: break, break off, discontinue
#     Definition [en]: prevent completion
#
#   Sense 16: → EN: waive, relinquish, forgo
#     Definition [en]: do without or cease to hold or adhere to
#
#   Sense 17: → EN: leave, leave alone, leave behind
#     Definition [en]: leave unchanged or undisturbed or refrain from taking
#
#   Sense 18: → EN: leave, result, lead
#     Definition [en]: have as a result or residue
#
#   Sense 19: → EN: let
#     Definition [en]: leave unchanged
#
#   Sense 20: → EN: leave, allow for, allow
#     Definition [en]: make a possibility or provide opportunity for; permit to be attainable or c...
#
#   Sense 21: → EN: abandon
#     Definition [en]: forsake, leave behind
#
#   Sense 22: → EN: neglect, pretermit, omit
#     Definition [en]: leave undone or leave out
#
#   Sense 23: → EN: release, relinquish, resign
#     Definition [en]: part with a possession or right
#
#   Sense 24: → EN: bequeath, will, leave
#     Definition [en]: leave or give by will after one's death
#
#   Sense 25: → EN: devolve, deteriorate, drop
#     Definition [en]: grow worse
#
#   Sense 26: → EN: hurt, ache, suffer
#     Definition [en]: feel physical pain
#
#   Sense 27: → EN: leave, go forth, go away
# ...
#     Definition [en]: give over to another for care or safekeeping
#
#   Sense 2: → EN: allow, take into account
#     Definition [en]: allow or plan for a certain possibility; concede the truth or validity of s...
#
#   Sense 3: → EN: poison
#     Definition [en]: administer poison to
#
#   Sense 4: → EN: poison, envenom
#     Definition [en]: add poison to
#
#   Sense 5: → EN: design
#     Definition [en]: plan something for a specific role or purpose or effect
#
#   Sense 6: → EN: design
#     Definition [en]: create the design for; create or execute in an artistic or highly skilled m...
#
#   Sense 7: → EN: permit, allow, let
#     Definition [en]: consent to, give permission
#
#   Sense 8: → EN: allow, appropriate, earmark
#     Definition [en]: give or assign a resource to a particular person or cause
#
# ======================================================================
# 📝 قص (v) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: abridge, foreshorten, abbreviate
#     Definition [en]: reduce in scope while retaining essential elements
#
#   Sense 2: → EN: ignore, disregard, snub
#     Definition [en]: refuse to acknowledge
#
#   Sense 3: → EN: relate
#     Definition [en]: have or establish a relationship to
#
#   Sense 4: → EN: cut
#     Definition [en]: separate with or as if with an instrument
#
#   Sense 5: → EN: report
#     Definition [en]: announce one's presence
#
#   Sense 6: → EN: report
#     Definition [en]: announce as the result of an investigation or experience or finding
#
#   Sense 7: → EN: reduce, cut down, cut back
#     Definition [en]: cut down on; make a reduction in
#
#   Sense 8: → EN: refer, pertain, relate
#     Definition [en]: be relevant to
#
# ======================================================================
# 📝 كرر (v) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: repeat, echo
#     Definition [en]: to say again or imitate
#
#   Sense 2: → EN: regenerate, renew
#     Definition [en]: reestablish on a new, usually improved, basis or make new or like new
#
#   Sense 3: → EN: inspire, animate, invigorate
#     Definition [en]: heighten or intensify
#
#   Sense 4: → EN: recur, repeat
#     Definition [en]: happen or occur again
#
#   Sense 5: → EN: polish, refine, fine-tune
#     Definition [en]: improve or perfect by pruning or polishing
#
#   Sense 6: → EN: repeat, reiterate, ingeminate
#     Definition [en]: to say, state, or perform again
#
#   Sense 7: → EN: refine, rectify
#     Definition [en]: reduce to a fine, unmixed, or pure state; separate from extraneous matter o...
#
#   Sense 8: → EN: correct, rectify, right
#     Definition [en]: make right or correct
#
# ======================================================================
# 📝 كشف عن (v) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: grow, develop, produce
#     Definition [en]: come to have or undergo a change of (physical features and attributes)
#
#   Sense 2: → EN: develop
#     Definition [en]: make visible by means of chemical solutions
#
#   Sense 3: → EN: develop, make grow
#     Definition [en]: cause to grow and differentiate in ways conforming to its natural developme...
#
#   Sense 4: → EN: discover, find
#     Definition [en]: make a discovery
#
#   Sense 5: → EN: learn, hear, get word
#     Definition [en]: get to know or become aware of, usually accidentally
#
#   Sense 6: → EN: unwrap, disclose, let on
#     Definition [en]: make known to the public information that was previously known only to a fe...
#
#   Sense 7: → EN: develop
#     Definition [en]: grow, progress, unfold, or evolve through a process of evolution, natural g...
#
#   Sense 8: → EN: publicize, publicise, air
#     Definition [en]: make public
#
# ======================================================================
# 📝 لوى القوس (v) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: draw
#     Definition [en]: represent by making a drawing of, as with a pencil, chalk, etc. on a surfac...
#
#   Sense 2: → EN: draw
#     Definition [en]: move or pull so as to cover or uncover something
#
#   Sense 3: → EN: draw
#     Definition [en]: require a specified depth for floating
#
#   Sense 4: → EN: draw
#     Definition [en]: flatten, stretch, or mold metal or glass, by rolling or by pulling it throu...
#
#   Sense 5: → EN: draw
#     Definition [en]: move or go steadily or gradually
#
#   Sense 6: → EN: draw
#     Definition [en]: elicit responses, such as objections, criticism, applause, etc.
#
#   Sense 7: → EN: pull, draw, force
#     Definition [en]: cause to move by pulling
#
#   Sense 8: → EN: draw
#     Definition [en]: bring or lead someone to a certain action or condition
#
# ======================================================================
# 📝 مهد (v) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: polish, smooth, smoothen
#     Definition [en]: make (a surface) shine
#
#   Sense 2: → EN: wheel, roll
#     Definition [en]: move along on or as if on wheels or a wheeled vehicle
#
#   Sense 3: → EN: flush, level, even out
#     Definition [en]: make level or straight
#
#   Sense 4: → EN: roll
#     Definition [en]: begin operating or running
#
#   Sense 5: → EN: flatten, drop
#     Definition [en]: lower the pitch of (musical notes)
#
#   Sense 6: → EN: smooth, smoothen
#     Definition [en]: make smooth or smoother, as if by rubbing
#
#   Sense 7: → EN: flatten
#     Definition [en]: make flat or flatter
#
#   Sense 8: → EN: roll, wander, swan
#     Definition [en]: move about aimlessly or without any destination, often in search of food or...
#
# ======================================================================
# 📝 نبه (v) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: stimulate, arouse, brace
#     Definition [en]: cause to be alert and energetic
#
#   Sense 2: → EN: urge, urge on, press
#     Definition [en]: force or impel in an indicated direction
#
#   Sense 3: → EN: arouse, sex, excite
#     Definition [en]: stimulate sexually
#
#   Sense 4: → EN: stimulate, excite
#     Definition [en]: act as a stimulant
#
#   Sense 5: → EN: wake up, awake, arouse
#     Definition [en]: stop sleeping
#
#   Sense 6: → EN: induce, stimulate, cause
#     Definition [en]: cause to do; cause to act in a specified manner
#
#   Sense 7: → EN: stimulate, shake, shake up
#     Definition [en]: stir the feelings, emotions, or peace of
#
#   Sense 8: → EN: recommend, urge, advocate
#     Definition [en]: push for something
#
# ======================================================================
# 📝 نحل (v) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: devolve, deteriorate, drop
#     Definition [en]: grow worse
#
#   Sense 2: → EN: dissolve, resolve, break up
#     Definition [en]: cause to go into a solution
#
#   Sense 3: → EN: melt, run, melt down
#     Definition [en]: reduce or cause to be reduced from a solid to a liquid state, usually by he...
#
#   Sense 4: → EN: loosen, loose
#     Definition [en]: make loose or looser
#
#   Sense 5: → EN: ache, yearn, yen
#     Definition [en]: have a desire for something or someone who is not present
#
#   Sense 6: → EN: dissolve, thaw, unfreeze
#     Definition [en]: become or cause to become soft or liquid
#
#   Sense 7: → EN: reduce, melt off, lose weight
#     Definition [en]: take off weight
#
#   Sense 8: → EN: disintegrate
#     Definition [en]: break into parts or components or lose cohesion or unity
#
# ======================================================================
# 📝 نظرة (v) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: roll, wander, swan
#     Definition [en]: move about aimlessly or without any destination, often in search of food or...
#
#   Sense 2: → EN: get, catch, capture
#     Definition [en]: succeed in catching or seizing, especially after a chase
#
#   Sense 3: → EN: cast, mold, mould
#     Definition [en]: form by pouring (e.g., wax or hot metal) into a cast or mold
#
#   Sense 4: → EN: capture, catch
#     Definition [en]: capture as if by hunting, snaring, or trapping
#
#   Sense 5: → EN: shed, cast, cast off
#     Definition [en]: get rid of
#
#   Sense 6: → EN: catch, pick up
#     Definition [en]: perceive with the senses quickly, suddenly, or momentarily
#
#   Sense 7: → EN: trip up, catch
#     Definition [en]: detect a blunder or misstep
#
#   Sense 8: → EN: catch, grab, take hold of
#     Definition [en]: take hold of so as to seize or restrain or stop the motion of
#
# ======================================================================
# 📝 هبط النهر (v) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: devolve, deteriorate, drop
#     Definition [en]: grow worse
#
#   Sense 2: → EN: spend, expend, drop
#     Definition [en]: pay out
#
#   Sense 3: → EN: drop
#     Definition [en]: to fall vertically
#
#   Sense 4: → EN: drop, knock off
#     Definition [en]: stop pursuing or acting
#
#   Sense 5: → EN: flatten, drop
#     Definition [en]: lower the pitch of (musical notes)
#
#   Sense 6: → EN: neglect, pretermit, omit
#     Definition [en]: leave undone or leave out
#
#   Sense 7: → EN: shed, cast, cast off
#     Definition [en]: get rid of
#
#   Sense 8: → EN: drop
#     Definition [en]: go down in value
#
# ======================================================================
# 📝 وطن (v) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: establish, found, plant
#     Definition [en]: set up or lay the groundwork for
#
#   Sense 2: → EN: sink, settle, go down
#     Definition [en]: go under
#
#   Sense 3: → EN: reconcile, patch up, make up
#     Definition [en]: come to terms
#
#   Sense 4: → EN: settle
#     Definition [en]: end a legal dispute by arriving at a settlement
#
#   Sense 5: → EN: settle, settle down
#     Definition [en]: settle into a position, usually on a surface or ground
#
#   Sense 6: → EN: prove, demonstrate, establish
#     Definition [en]: establish the validity of something, as by an example, explanation or exper...
#
#   Sense 7: → EN: ensconce, settle
#     Definition [en]: fix firmly
#
#   Sense 8: → EN: lay down, establish, make
#     Definition [en]: institute, enact, or establish
#
# ======================================================================
# 📝 وفى بالمرام (v) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: meet, encounter, play
#     Definition [en]: contend against an opponent in a sport, game, or battle
#
#   Sense 2: → EN: meet, match, cope with
#     Definition [en]: satisfy or fulfill
#
#   Sense 3: → EN: meet, run into, encounter
#     Definition [en]: come together
#
#   Sense 4: → EN: meet, satisfy, fill
#     Definition [en]: fill or meet a want or need
#
#   Sense 5: → EN: meet, fit, conform to
#     Definition [en]: satisfy a condition or restriction
#
#   Sense 6: → EN: touch, adjoin, meet
#     Definition [en]: be in direct physical contact with; make contact
#
#   Sense 7: → EN: meet, get together
#     Definition [en]: get together socially or for a specific purpose
#
#   Sense 8: → EN: meet, gather, assemble
#     Definition [en]: collect in one place
#
# ======================================================================
# 📝 وقع في شرك (v) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: trip up, catch
#     Definition [en]: detect a blunder or misstep
#
#   Sense 2: → EN: predominate, dominate, rule
#     Definition [en]: be larger in number, quantity, power, status or importance
#
#   Sense 3: → EN: restrict, restrain, trammel
#     Definition [en]: place limits on (extent or access)
#
#   Sense 4: → EN: catch, pick up
#     Definition [en]: perceive with the senses quickly, suddenly, or momentarily
#
#   Sense 5: → EN: get, catch, capture
#     Definition [en]: succeed in catching or seizing, especially after a chase
#
#   Sense 6: → EN: catch, grab, take hold of
#     Definition [en]: take hold of so as to seize or restrain or stop the motion of
#
#   Sense 7: → EN: trap, entrap, snare
#     Definition [en]: catch in or as if in a trap
#
#   Sense 8: → EN: capture, catch
#     Definition [en]: capture as if by hunting, snaring, or trapping
#
# ======================================================================
# 📝 مَجْمُوعَة (n) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: set
#     Definition [en]: (mathematics) an abstract collection of numbers or symbols
#
#   Sense 2: → EN: pack
#     Definition [en]: a complete collection of similar things
#
#   Sense 3: → EN: bunch, lot, caboodle
#     Definition [en]: any collection in its entirety
#
#   Sense 4: → EN: collection, aggregation, accumulation
#     Definition [en]: several things grouped together or considered as a whole
#
#   Sense 5: → EN: set
#     Definition [en]: a group of things of the same kind that belong together and are so used
#
#   Sense 6: → EN: collection, compendium
#     Definition [en]: a publication containing a variety of works
#
#   Sense 7: → EN: combination
#     Definition [en]: a group of people (often temporary) having a common purpose
#
#   Sense 8: → EN: set, circle, band
#     Definition [en]: an unofficial association of people or groups
#
# ======================================================================
# 📝 وَافَقَ (v) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: match, fit
#     Definition [en]: make correspond or harmonize
#
#   Sense 2: → EN: agree, hold, concur
#     Definition [en]: be in accord; be in agreement
#
#   Sense 3: → EN: suit
#     Definition [en]: be agreeable or acceptable
#
#   Sense 4: → EN: agree
#     Definition [en]: achieve harmony of opinion, feeling, or purpose
#
#   Sense 5: → EN: accept
#     Definition [en]: consider or hold as true
#
#   Sense 6: → EN: affirm
#     Definition [en]: say yes to
#
#   Sense 7: → EN: meet, match, cope with
#     Definition [en]: satisfy or fulfill
#
#   Sense 8: → EN: nod
#     Definition [en]: express or signify by nodding
#
# ======================================================================
# 📝 وَحْدَة (n) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: merging, meeting, coming together
#     Definition [en]: the act of joining together as one
#
#   Sense 2: → EN: unit
#     Definition [en]: an individual or group or structure or other entity regarded as a structura...
#
#   Sense 3: → EN: unit of measurement, unit
#     Definition [en]: any division of quantity accepted as a standard of measurement or exchange
#
#   Sense 4: → EN: whole, unit
#     Definition [en]: an assemblage of parts that is regarded as a single entity
#
#   Sense 5: → EN: unit, building block
#     Definition [en]: a single undivided natural thing occurring in the composition of something ...
#
#   Sense 6: → EN: unit
#     Definition [en]: a single undivided whole
#
#   Sense 7: → EN: unit, social unit
#     Definition [en]: an organization regarded as part of a larger social group
#
#   Sense 8: → EN: block
#     Definition [en]: housing in a large building that is divided into separate units
#
# ======================================================================
# 📝 خَطّ (n) - 8 senses
# ======================================================================
#
#   Sense 1: → EN: line
#     Definition [en]: a length (straight or curved) without breadth or thickness; the trace of a ...
#
#   Sense 2: → EN: line
#     Definition [en]: a spatial location defined by a real or imaginary unidimensional extent
#
#   Sense 3: → EN: handwriting
#     Definition [en]: the activity of writing by hand
#
#   Sense 4: → EN: line
#     Definition [en]: a mark that is long relative to its width
#
#   Sense 5: → EN: line
#     Definition [en]: a single frequency (or very narrow band) of radiation in a spectrum
#
#   Sense 6: → EN: path, route, itinerary
#     Definition [en]: an established line of travel or access
#
#   Sense 7: → EN: line
#     Definition [en]: a fortified position (especially one marking the most forward position of t...
#
#   Sense 8: → EN: row
#     Definition [en]: a long continuous strip (usually running horizontally)

# %%
# Statistical breakdown of highly polysemous words
print("📊 Statistics: Words with 8+ Senses")
print("=" * 50)

if highly_polysemous:
    # Group by POS
    pos_breakdown = Counter(word.pos for word, _ in highly_polysemous)
    print("\nBy Part of Speech:")
    for pos, count in pos_breakdown.most_common():
        pos_name = {'n': 'Noun', 'v': 'Verb', 'a': 'Adjective', 'r': 'Adverb', 's': 'Adj. Satellite'}.get(pos, pos)
        print(f"  {pos_name:15} {count:3} words")
    
    # Sense count distribution
    sense_counts = [num for _, num in highly_polysemous]
    print(f"\nSense count range: {min(sense_counts)} - {max(sense_counts)}")
    print(f"Average senses:    {sum(sense_counts)/len(sense_counts):.1f}")
    
    # Group by sense count
    print("\nDistribution by sense count:")
    sense_dist = Counter(sense_counts)
    for count in sorted(sense_dist.keys()):
        words_at_count = [w.lemma() for w, n in highly_polysemous if n == count]
        print(f"  {count} senses: {len(words_at_count)} words")
        # Show first 3 examples
        examples = words_at_count[:3]
        if examples:
            print(f"           e.g., {', '.join(examples)}")
else:
    print("No words with 8+ senses found.")
# Out:
# 📊 Statistics: Words with 8+ Senses
# ==================================================
#
# By Part of Speech:
#   Verb            679 words
#   Noun             48 words
#
# Sense count range: 8 - 48
# Average senses:    14.4
#
# Distribution by sense count:
#   8 senses: 130 words
#            e.g., أهْمل, أكّد, أمر
#   9 senses: 85 words
#            e.g., شكْل, أعْلن, أظْهر
#   10 senses: 66 words
#            e.g., شمل, أضاف, أنْشأ
#   11 senses: 80 words
#            e.g., شغّل, شكّل, أطْلق
#   12 senses: 52 words
#            e.g., شكر, شرع, شرح
#   13 senses: 55 words
#            e.g., أدخل, أقام, ضغط
#   14 senses: 32 words
#            e.g., أجاز, أزاح, ضبط
#   15 senses: 24 words
#            e.g., شاهد, صادف, دخل
#   16 senses: 25 words
#            e.g., أراد, حسب, صان
#   17 senses: 9 words
#            e.g., أمْسك, قابل, سال
#   18 senses: 14 words
#            e.g., عمل, عزف, حاكم
#   19 senses: 16 words
#            e.g., ذهب, أعْطى, أسر
#   20 senses: 12 words
#            e.g., ضرب, فرق, قاسى
#   21 senses: 11 words
#            e.g., أعاد, عاق, غلق
#   22 senses: 11 words
#            e.g., حجز, باع, برز
#   23 senses: 12 words
#            e.g., عنى, عرف, دعا
#   24 senses: 14 words
#            e.g., شارك, عانى, حكم
#   25 senses: 8 words
#            e.g., أصاب, كبح, سافر
#   26 senses: 10 words
#            e.g., أخذ, عالج, فعل
#   27 senses: 8 words
#            e.g., أزال, أدار, بحث
#   28 senses: 2 words
#            e.g., فحص, حدد
#   29 senses: 4 words
#            e.g., حضر, دعم, هاجم
#   30 senses: 5 words
#            e.g., لاحظ, نفذ, نجح
#   31 senses: 3 words
#            e.g., نقل, أطلق, وضع
#   32 senses: 8 words
#            e.g., أشار, نال, نزل
#   33 senses: 4 words
#            e.g., عقد, بدأ, دفع
#   34 senses: 5 words
#            e.g., نظم, قاد, قطع
#   35 senses: 2 words
#            e.g., شغل, استمر
#   36 senses: 4 words
#            e.g., عرض, أضعف, أنتج
#   37 senses: 1 words
#            e.g., وصل
#   38 senses: 1 words
#            e.g., فهم
#   39 senses: 3 words
#            e.g., عبر, رحل, وقع
#   41 senses: 3 words
#            e.g., حدث, ظهر, ترك
#   42 senses: 1 words
#            e.g., نشر
#   43 senses: 1 words
#            e.g., حول
#   44 senses: 1 words
#            e.g., رافق
#   45 senses: 2 words
#            e.g., حمل, حقق
#   46 senses: 1 words
#            e.g., فصل
#   47 senses: 1 words
#            e.g., أثار
#   48 senses: 1 words
#            e.g., أدرك

# %%
# Analyze the semantic variety of highly polysemous words
print("🎯 Semantic Analysis of Highly Polysemous Words")
print("=" * 60)

# Create expanded wordnet for taxonomy access
arb_expanded = wn.Wordnet('omw-arb:1.4', expand='omw-en:1.4')

if highly_polysemous:
    for word, num_senses in highly_polysemous[:5]:  # Top 5 most polysemous
        print(f"\n{'─'*60}")
        print(f"📌 {word.lemma()} ({num_senses} senses)")
        print("─" * 60)
        
        # Collect all synsets and their hypernyms to find common themes
        hypernym_counts = Counter()
        pos_in_senses = Counter()
        
        for sense in word.senses():
            synset = sense.synset()
            pos_in_senses[synset.pos] += 1
            
            # Get hypernyms using expanded wordnet
            arb_ss = arb_expanded.synset(synset.id)
            if arb_ss:
                for hyp in arb_ss.hypernyms():
                    hyp_lemmas = [w.lemma() for w in hyp.words()]
                    if hyp_lemmas:
                        hypernym_counts[hyp_lemmas[0]] += 1
                    else:
                        # Get English hypernym
                        if hyp.ili:
                            en_hyps = en.synsets(ili=hyp.ili.id)
                            if en_hyps:
                                en_lemmas = [w.lemma() for w in en_hyps[0].words()]
                                if en_lemmas:
                                    hypernym_counts[f"[{en_lemmas[0]}]"] += 1
        
        # Show POS distribution within senses
        if len(pos_in_senses) > 1:
            print(f"  POS variety: {dict(pos_in_senses)}")
        
        # Show common hypernyms (semantic categories)
        if hypernym_counts:
            print(f"  Common hypernyms (semantic categories):")
            for hyp, count in hypernym_counts.most_common(5):
                print(f"    • {hyp}: {count} senses")
        
        # Show all senses briefly
        print(f"\n  All senses:")
        for i, sense in enumerate(word.senses(), 1):
            synset = sense.synset()
            defn, lang = get_definition(synset, en)
            lang_tag = f"[{lang}]" if lang else ""
            print(f"    {i}. {lang_tag} {defn[:50]}{'...' if len(defn) > 50 else ''}")
# Out:
# 🎯 Semantic Analysis of Highly Polysemous Words
# ============================================================
#
# ────────────────────────────────────────────────────────────
# 📌 أدرك (48 senses)
# ────────────────────────────────────────────────────────────
#   Common hypernyms (semantic categories):
#     • أدْرك: 4 senses
#     • إِعْتبر: 2 senses
#     • فهِم: 2 senses
#     • تحرّك: 2 senses
#     • أسْفر: 1 senses
#
#   All senses:
#     1. [en] have a feeling or perception about oneself in reac...
#     2. [en] get to know or become aware of, usually accidental...
#     3. [en] come as a logical consequence; follow logically
#     4. [en] travel past
#     5. [en] come together
#     6. [en] be fully aware or cognizant of
#     7. [en] show approval or appreciation of
#     8. [en] perceive to be the same
#     9. [en] perceive by sight or have the power to perceive by...
#     10. [en] get the meaning of something
#     11. [en] take something or somebody with oneself somewhere
#     12. [en] pick out, select, or choose from a number of alter...
#     13. [en] observe, check out, and look over carefully or ins...
#     14. [en] interpret something in a certain way; convey a par...
#     15. [en] receive willingly something given or offered
#     16. [en] imagine; conceive of; see in one's mind
#     17. [en] deem to be
#     18. [en] become conscious of
#     19. [en] go to see a place, as for entertainment
#     20. [en] express greetings upon meeting someone
#     21. [en] to travel behind, go after, come after
#     22. [en] take into one's possession
#     23. [en] perceive (an idea or situation) mentally
#     24. [en] make sense of; assign a meaning to
#     25. [en] remove something concrete, as by lifting, pushing,...
#     26. [en] express obligation, thanks, or gratitude for
#     27. [en] be felt or perceived in a certain way
#     28. [en] know and comprehend the nature or meaning of
#     29. [en] take somebody somewhere
#     30. [en] make a film or photograph of something
#     31. [en] be the successor (of)
#     32. [en] be a student of a certain subject
#     33. [en] go or live through
#     34. [en] watch attentively
#     35. [en] follow with the eyes or the mind
#     36. [en] perceive by a physical sensation, e.g., coming fro...
#     37. [en] choose and follow; as of theories, ideas, policies...
#     38. [en] make real or concrete; give reality or substance t...
#     39. [en] pass into or through, often by overcoming resistan...
#     40. [en] require as useful, just, or proper
#     41. [en] behave in accordance or in agreement with
#     42. [en] undergo an emotional sensation or be in a particul...
#     43. [en] to become aware of through the senses
#     44. [en] overcome, as with emotions or perceptual stimuli
#     45. [en] admit into a group or community
#     46. [en] make a hole into
#     47. [en] follow in or as if in pursuit
#     48. [en] take by force
#
# ────────────────────────────────────────────────────────────
# 📌 أثار (47 senses)
# ────────────────────────────────────────────────────────────
#   Common hypernyms (semantic categories):
#     • أثّر: 4 senses
#     • اِسْتبْدل: 3 senses
#     • عدّل: 3 senses
#     • [propose]: 2 senses
#     • أحْدث: 2 senses
#
#   All senses:
#     1. [en] excite to an abnormal condition, or chafe or infla...
#     2. [en] be employed
#     3. [en] find the solution to (a problem or question) or un...
#     4. [en] perform an action, or work out or perform (an acti...
#     5. [en] cause annoyance in; disturb, especially by minor i...
#     6. [en] call to mind
#     7. [en] undergo (as of injuries and illnesses)
#     8. [en] propose formally; in a debate or parliamentary mee...
#     9. [en] move while supporting, either in a vehicle or in o...
#     10. [en] stir the feelings, emotions, or peace of
#     11. [en] make worse
#     12. [en] call forth (emotions, feelings, and responses)
#     13. [en] cause to work
#     14. [en] move so as to change position, perform a nontransl...
#     15. [en] pass through
#     16. [en] heighten or intensify
#     17. [en] move deeply
#     18. [en] send from one person or place to another
#     19. [en] make hot or hotter
#     20. [en] make something, usually for a specific function
#     21. [en] come into the possession of something concrete or ...
#     22. [en] have and exert influence or effect
#     23. [en] reach a destination; arrive by movement or progres...
#     24. [en] cause to be alert and energetic
#     25. [en] stimulate sexually
#     26. [en] change location; move, travel, or proceed, also me...
#     27. [en] act as a stimulant
#     28. [en] push for something
#     29. [en] have a turn; make one's move in a game
#     30. [en] summon into action or bring into existence, often ...
#     31. [en] cause to burn or combust
#     32. [en] come to have or undergo a change of (physical feat...
#     33. [en] stop sleeping
#     34. [en] have an emotional or cognitive impact upon
#     35. [en] exert oneself by doing mental or physical work for...
#     36. [en] cause to move or shift into a new position or plac...
#     37. [en] give certain properties to something
#     38. [en] use or manipulate to one's advantage
#     39. [en] hold spellbound
#     40. [en] go or come after and bring or take back
#     41. [en] force or impel in an indicated direction
#     42. [en] proceed towards a goal or along a path or through ...
#     43. [en] cause to do; cause to act in a specified manner
#     44. [en] go sour or spoil
#     45. [en] succeed in catching or seizing, especially after a...
#     46. [en] make furious
#     47. [en] move something or somebody around; usually over lo...
#
# ────────────────────────────────────────────────────────────
# 📌 فصل (46 senses)
# ────────────────────────────────────────────────────────────
#   Common hypernyms (semantic categories):
#     • تغيّر: 3 senses
#     • فصل: 3 senses
#     • اِسْتبْدل: 2 senses
#     • حسب: 2 senses
#     • نقص: 2 senses
#
#   All senses:
#     1. [en] call forth (emotions, feelings, and responses)
#     2. [en] make known to the public information that was prev...
#     3. [en] force to leave or move out
#     4. [en] judge tentatively or form an estimate of (quantiti...
#     5. [en] divide into components or constituents
#     6. [en] separate into parts or portions
#     7. [en] bring to an end; settle conclusively
#     8. [en] cause to go off
#     9. [en] make a division or separation
#     10. [en] refuse to acknowledge
#     11. [en] go under
#     12. [en] arrange or order by classes or categories
#     13. [en] pour forth or release
#     14. [en] discontinue an association or relation; go differe...
#     15. [en] remove something concrete, as by lifting, pushing,...
#     16. [en] cut down on; make a reduction in
#     17. [en] establish after a calculation, investigation, expe...
#     18. [en] come to terms
#     19. [en] reduce in scope while retaining essential elements
#     20. [en] pronounce judgment on
#     21. [en] dispose of
#     22. [en] go one's own way; move apart
#     23. [en] remove from a position or an office
#     24. [en] terminate the employment of; discharge from an off...
#     25. [en] put out of its usual place, position, or relations...
#     26. [en] mark as different
#     27. [en] perform a division
#     28. [en] come apart
#     29. [en] settle into a position, usually on a surface or gr...
#     30. [en] end a legal dispute by arriving at a settlement
#     31. [en] reach, make, or come to a decision about something
#     32. [en] force, take, or pull apart
#     33. [en] destroy the integrity of; usually by force; cause ...
#     34. [en] form a critical opinion of
#     35. [en] cause to move or shift into a new position or plac...
#     36. [en] put out or expel from a place
#     37. [en] make disconnected, disjoin or unfasten
#     38. [en] determine the result of (a competition)
#     39. [en] fix firmly
#     40. [en] come to be detached
#     41. [en] ruin completely
#     42. [en] separate with or as if with an instrument
#     43. [en] act as a barrier between; stand between
#     44. [en] become separated into pieces or fragments
#     45. [en] go off or discharge
#     46. [en] eliminate (a substance)
#
# ────────────────────────────────────────────────────────────
# 📌 حمل (45 senses)
# ────────────────────────────────────────────────────────────
#   Common hypernyms (semantic categories):
#     • حمل: 3 senses
#     • أخْمد: 2 senses
#     • عدّل: 2 senses
#     • اِسْتبْدل: 2 senses
#     • تحدّث: 1 senses
#
#   All senses:
#     1. [en] continue talking
#     2. [en] assign a duty, responsibility or obligation to
#     3. [en] serve as a means for expressing something
#     4. [en] hold the attention of
#     5. [en] go on a campaign; go off to war
#     6. [en] have rightfully; of rights, titles, and offices
#     7. [en] interpret something in a certain way; convey a par...
#     8. [en] be pregnant with
#     9. [en] require as useful, just, or proper
#     10. [en] take into one's possession
#     11. [en] pick out, select, or choose from a number of alter...
#     12. [en] take something or somebody with oneself somewhere
#     13. [en] bring forth
#     14. [en] remove something concrete, as by lifting, pushing,...
#     15. [en] demand payment
#     16. [en] direct the course of; manage or control
#     17. [en] support or hold in a certain manner
#     18. [en] keep in mind or convey as a conviction or view
#     19. [en] lessen the intensity of; temper; hold in restraint...
#     20. [en] fill or load to capacity
#     21. [en] raise from a lower to a higher position
#     22. [en] move while holding up or supporting
#     23. [en] take somebody somewhere
#     24. [en] keep in a certain state, position, or activity; e....
#     25. [en] blame for, make a claim of wrongdoing or misbehavi...
#     26. [en] be a student of a certain subject
#     27. [en] have or possess, either in a concrete or an abstra...
#     28. [en] take by force
#     29. [en] make a film or photograph of something
#     30. [en] receive willingly something given or offered
#     31. [en] contain or hold; have within
#     32. [en] cause formation of a net electrical charge in or o...
#     33. [en] cause to be admitted; of persons to an institution
#     34. [en] admit into a group or community
#     35. [en] to close within bounds, limit or hold back from mo...
#     36. [en] be in accord; be in agreement
#     37. [en] be relevant to
#     38. [en] move while supporting, either in a vehicle or in o...
#     39. [en] have with oneself; have on one's person
#     40. [en] keep from exhaling or expelling
#     41. [en] behave in a certain manner
#     42. [en] have or hold in one's hands or grip
#     43. [en] fill or place a load on
#     44. [en] declare to be
#     45. [en] keep or maintain in unaltered condition; cause to ...
#
# ────────────────────────────────────────────────────────────
# 📌 حقق (45 senses)
# ────────────────────────────────────────────────────────────
#   Common hypernyms (semantic categories):
#     • أحْدث: 2 senses
#     • اِعْتبر: 2 senses
#     • أدْرك: 2 senses
#     • أتى: 1 senses
#     • تصوّر: 1 senses
#
#   All senses:
#     1. [en] reach a point in time, or a certain state or level
#     2. [en] require as useful, just, or proper
#     3. [en] remove something concrete, as by lifting, pushing,...
#     4. [en] imagine; conceive of; see in one's mind
#     5. [en] put in effect
#     6. [en] observe, check out, and look over carefully or ins...
#     7. [en] make a film or photograph of something
#     8. [en] to gain with effort
#     9. [en] deem to be
#     10. [en] reach a destination, either real or abstract
#     11. [en] take by force
#     12. [en] go to see a place, as for entertainment
#     13. [en] find out, learn, or determine with certainty, usua...
#     14. [en] go or live through
#     15. [en] bring out for display
#     16. [en] make real or concrete; give reality or substance t...
#     17. [en] take somebody somewhere
#     18. [en] be compatible, similar or consistent; coincide in ...
#     19. [en] regard highly; think much of
#     20. [en] come together
#     21. [en] perceive (an idea or situation) mentally
#     22. [en] meet the requirements or expectations of
#     23. [en] bring forth or yield
#     24. [en] fill or meet a want or need
#     25. [en] make sense of; assign a meaning to
#     26. [en] admit into a group or community
#     27. [en] examine so as to determine accuracy, quality, or c...
#     28. [en] create or manufacture a man-made product
#     29. [en] perceive by sight or have the power to perceive by...
#     30. [en] pick out, select, or choose from a number of alter...
#     31. [en] interpret something in a certain way; convey a par...
#     32. [en] be a student of a certain subject
#     33. [en] establish after a calculation, investigation, expe...
#     34. [en] question or examine thoroughly and closely
#     35. [en] get to know or become aware of, usually accidental...
#     36. [en] come to have or undergo a change of (physical feat...
#     37. [en] hold dear
#     38. [en] conduct an inquiry or investigation of
#     39. [en] take into one's possession
#     40. [en] take something or somebody with oneself somewhere
#     41. [en] lessen the intensity of; temper; hold in restraint...
#     42. [en] come into being; become reality
#     43. [en] produce
#     44. [en] receive willingly something given or offered
#     45. [en] learn or discover with certainty

# %% [markdown]
# <a id='synsets'></a>
# ## 5. Exploring Synsets

# %%
# Get sample synsets
print("🔮 Sample Arabic Synsets")
print("=" * 70)

sample_synsets = list(arb.synsets())[:10]
for ss in sample_synsets:
    lemmas = [w.lemma() for w in ss.words()]
    defn, lang = get_definition(ss, en)
    en_words = get_english_words(ss, en)
    ili = ss.ili.id if ss.ili else "N/A"
    
    print(f"\nSynset: {ss.id}")
    print(f"  POS: {ss.pos}")
    print(f"  ILI: {ili}")
    print(f"  Arabic words: {', '.join(lemmas)}")
    if en_words:
        print(f"  English words: {', '.join(en_words)}")
    lang_tag = f"[{lang}]" if lang else ""
    print(f"  Definition {lang_tag}: {defn[:65]}..." if len(defn) > 65 else f"  Definition {lang_tag}: {defn}")
# Out:
# 🔮 Sample Arabic Synsets
# ======================================================================
#
# Synset: omw-arb-03012209-a
#   POS: a
#   ILI: i17226
#   Arabic words: أوّلِي, أَوَّلِي
#   English words: prime
#   Definition [en]: of or relating to or being an integer that cannot be factored int...
#
# Synset: omw-arb-13983515-n
#   POS: n
#   ILI: i110421
#   Arabic words: ظلْماء, دُهْمة, عتْمة, ظلام, ظُلْمة, غلس, قتْمة, ظَلْماء, دُهْمَة
#   English words: dark, darkness
#   Definition [en]: absence of light or illumination
#
# Synset: omw-arb-13659760-n
#   POS: n
#   ILI: i108497
#   Arabic words: كِيْلُو مِتْر, كم
#   English words: kilometer, kilometre, km, klick
#   Definition [en]: a metric unit of length equal to 1000 meters (or 0.621371 miles)
#
# Synset: omw-arb-09885145-n
#   POS: n
#   ILI: i88763
#   Arabic words: شارِي, مُشْترٍ, مُشْترِي
#   English words: buyer, purchaser, emptor, vendee
#   Definition [en]: a person who buys
#
# Synset: omw-arb-02316707-n
#   POS: n
#   ILI: i47722
#   Arabic words: شائِك الجِلْد
#   English words: echinoderm
#   Definition [en]: marine invertebrates with tube feet and five-part radially symmet...
#
# Synset: omw-arb-04980463-n
#   POS: n
#   ILI: i63173
#   Arabic words: شذا, أرج, أرِيج, الرّائحة الزّكية, عبق, عبِير, عِطْر, حلاوة, طِيْب, باقة, ريّا, رِيْح
#   English words: bouquet, fragrance, fragrancy, redolence, sweetness
#   Definition [en]: a pleasingly sweet olfactory property
#
# Synset: omw-arb-05169813-n
#   POS: n
#   ILI: i64149
#   Arabic words: شأن, أهمِّيّة
#   English words: significance
#   Definition [en]: the quality of being significant
#
# Synset: omw-arb-05670710-n
#   POS: n
#   ILI: i66717
#   Arabic words: شأن, همّ
#   English words: concern
#   Definition [en]: something that interests you because it is important or affects y...
#
# Synset: omw-arb-05671325-n
#   POS: n
#   ILI: i66720
#   Arabic words: شأن, شيء, أمْر, مسْألة
#   English words: matter, affair, thing
#   Definition [en]: a vaguely specified concern
#
# Synset: omw-arb-05814650-n
#   POS: n
#   ILI: i67438
#   Arabic words: شأن, مسْألة, قضِيّة
#   English words: issue
#   Definition [en]: an important question that is in dispute and must be settled

# %%
# Find synsets with multiple members (synonyms)
print("\n👥 Synsets with Multiple Arabic Words (Synonyms)")
print("=" * 60)

multi_word_synsets = []
for ss in arb.synsets():
    words = ss.words()
    if len(words) > 1:
        multi_word_synsets.append((ss, words))

multi_word_synsets.sort(key=lambda x: len(x[1]), reverse=True)

print(f"Found {len(multi_word_synsets)} synsets with 2+ Arabic words\n")

for ss, words in multi_word_synsets[:15]:
    lemmas = ', '.join([w.lemma() for w in words])
    defn, lang = get_definition(ss, en)
    en_words = get_english_words(ss, en)
    
    print(f"[{len(words)} words] {lemmas}")
    lang_tag = f"[{lang}]" if lang else ""
    en_tag = f" = {', '.join(en_words[:3])}" if en_words else ""
    print(f"         → {lang_tag} {defn[:45]}...{en_tag}" if len(defn) > 45 else f"         → {lang_tag} {defn}{en_tag}")
# Out:
# 👥 Synsets with Multiple Arabic Words (Synonyms)
# ============================================================
# Found 6232 synsets with 2+ Arabic words
#
# [83 words] شرد, طاف, هام, تجوّل, ترحّل, تسكّع, أضاع, أطلق, ألقى, إتخذ مكانا, إجتاز سيرا على الأقدام, إختار دورا للممثل, إندفع للأمام, امتد, انبسط, انجرف, انحرف, انضم, تاه, تتكسر الأمواج, تجول, تحدث على نحو مفكك, تدحرج, تدفعه الرياح, تدفق, تراصف, ترحل, ترصن, تسكع, تسلق, تسول, تعرش, تكور, تلوى, تمايل, تمرق, تنزه, جاب, جاب البحار, جرى, جرى مع التيار, جول, جول في, حاد, حام, حظ, خرج في نزهة, خرف, خضع بلد للقانون, خطا بتثاقل, دخل, دفع, دوى, رتب, رعى الماشية, رغا, رمى, سافر بدون هدف, سافر كثيرا, سبك, سكب الحديد, سوق بقوة الرياح, شكل, صب, صوب, ضرب الأرض, ضل, طرح أرضا, طرق الحديد, طفا, عقد, غبار, غطى بركام, قذف, قرع الطبل, ملس, مهد, نظرة, نظم, هذى, هيئة, واصل سيره على القدمين, وزع
#          → [en] move about aimlessly or without any destinati... = roll, wander, swan
# [81 words] اِنْفصل, أذاع, أرهق, أضعف, أفشى, أوقف, إستبدل قطع النقد, إنطلق بسرعة خاطفة, اختتم, استخلص, افترق, اقتحم, انتهك, انسحب, انشق, انصرف, انطلق, انفجر, انفصل, انقسم, تجزأ, تخلى, تدهور, ترك, تساقط, تشعب, تطور, تفرق, تفكك, تفوق, تقطع, تكسر, تمزق, توقف عن شىء, جرح, جزأ, حطم, خان, خرق, خفض السعر, دحض, رحل, روض, سحق, شارك, شق, شق سطح كذا, شق طريقه, صدع, عزل عن بقية, عود, غير إتجاه شىء ما, فاصل, فتت, فر من, فرق, فرق الشعر, فرق الشمل, فصل, فض, فضى بمكنون صدره, فك, فكك, فلس, فلق, قسم, قطع, قطع الصمت, كسر, كسر إضرابا, كسر الثلج, ميز, نزل رتبته, نصح, نفض, نقض, وزع, وشى ب, وضع حد, وضع حدا, وقع في الأفلاس
#          → [en] discontinue an association or relation; go di... = separate, part, split up
# [69 words] أغْرى, أقْنع, اِضْطرّ, حفّز, حثّ, دعى, جعل, سبّب, أثار, أحدث, أحرز هدفا, أخرج, أسعد, أصاب, أضرم, أغرى, أكرهه على, أنتج, أيد فكرة ما, إتخذ قرارا, إستقرى يتتبع الجزئيات, إنتقم من, إندفع نحو, استمال, استنتج, اشتمل, اضطر, اعتبر, اندفع, بدأ عملا, بنى, تجبر, تصرف, تضمن, تملق, تناول, جلب, حاز, حث, حرك, حصل, حضر, حفز, حول, حيز, خلق, ربح, زار, شن, صنع, صير فى حالة, ضم جهده, عجل الولادة, عوض, عين, غلق, فاز, فاز ب, فعل, قاضى, قنع, كسب, ملك, نال, نبه, نجح, نشط, هيأ, وصل
#          → [en] cause to do; cause to act in a specified mann... = induce, stimulate, cause
# [69 words] أجبر العظم, أخرج, أخمد, أربك, أسس, ألقى اللوم على فلان, إنجبر للعظم, استثمر, استقر, استهل, اعتبر, اقترح, بدأ, برم, بسط, تأهب, تحضن البيض, تصنع للطبيب, تظاهر, تكلف, تلاءم, ثبت, جمد, حدث, حدد, حدد موعدا, حرض, خدع, خلق مشاكل, دبر, دخر, دفن, راهن, ربط, رتب, رسم, رصع, رقص وجها لوجه, ركب, روج الإشاعات, زرع, سجل رقما قياسيا, صاغ, صنف, ضبط, طرح, طرح سؤالا, طلب, عرض, عين, عين شخصا في وظيفة, غرب, فاز بمرتبة مرموقة, فتل, فرض, قذف الكرة, قرر, كان في موقع, كمن, ميز شخصا, نظم, هيأ المائدة, وازن بين, وضع, وضعه فى موضع معين, وقع, وقف أمام الفنان ليرسمه, يوجد عملا ل, وَضَعَ
#          → [en] put into a certain place or abstract location = put, set, place
# [64 words] إِنْتهى, اِنْتقل إلى الرّفِيق الأعْلى, فنِي, هلك, لفظ النّفس الأخِير, مات, رحل, سلّم الرُّوح, أخمد, أدى, أصبح, أصبح أقل تعرضا, أصبح لا مباليا, أضعف, أعد, أقر ب, ألغى إعلان, أهمل, إجتاز بنجاح, إنتقل إلى, استهلك, اعتزم, انطلق, انهار, تبادل, تبرز, تجاوز, تحرق شوقا, تخلى عن دوره في اللعب, تخمد, تعفن, تغاضى, تغوط, تنقضي, جهل, حدث, خرج, دار, ذهب, زفر, ساعد على, سافر, سلم الروح, سير, شق طريقه, عبر, عرف ب, غادر, غادر المسرح, فقد, فني, قال, لجأ, لفظ النفس الأخير, مات من الجوع, مر, مر الكرة للاعب آخر, مرر, مشى, مضى, موت, نجح, خَرَجَ, خَرَجَ من الدُّنْيَا
#          → [en] pass from physical life and lose all bodily a... = die, decease, perish
# [62 words] أعْلن, أباح, أبْلغ, أخْبر, كشف, لفظ, منح, نشر, قدّم, أبدى للعيان, أذاع, أرهق, أضعف, أفشى سرا, أوحى إلى, أوقف, إستبدل قطع النقد, اقتحم, اكتشف, انتهك, انفجر, باح, باح بسر, تخلى, ترك, تعرى, تفوق, تقطع, تكسر, جرح, جزأ, حطم, خرق, خفض السعر, دحض, روض, سحق, شق سطح كذا, شق طريقه, ظهر, عرض, عود, غير إتجاه شىء ما, فاصل, فر من, فرق الشمل, فصل, فضح, فضى ب, فضى بمكنون صدره, فلس, قطع, قطع الصمت, كسر, كسر إضرابا, كشف عن, نزل رتبته, نصح, نقض, هجر, وضع حدا, وقع في الأفلاس
#          → [en] make known to the public information that was... = unwrap, disclose, let on
# [62 words] أحدث, أحرز, أحرز هدفا, أسعد, أصاب, أصاب الهدف, أضرم, أكرهه على, أنتج, إتخذ قرارا, إنتصر, إندفع نحو, اتصل, ارتطم, ازداد, اعتبر, اكتشف, امتد, اندفع, بدأ عملا, بسط, بلغ, بنى, تأول, تجبر, تحصل, تصرف, تملق, تناول, توافق مع, جعل, حضر, حقق, حقق إنتصار, حول, خلق, ربح, سدد, شن, صد, صدم, صنع, ضرب, عوض, عين, غلق, فاز, فعل, قدم, كان في متناول اليد, كسب, لاقى نجاحا, مد يده للوصول ل, نال, نجح, نجز, هاجم, هيأ, وجد, وصل, وفق إلى, وَصَلَ
#          → [en] reach a destination, either real or abstract = reach, make, attain
# [59 words] اٍحْتوى, حوى, أبقى, أطاق, أعطى, أمسك, أنتج, اتسع, احتفظ, احتوى, استحوذ, استمر, استولى, اشتمل, التفت, بلغ مسافة ما, تحمل, تصرف, تصور, تضمن, تعقب, تنشر, حاكم, حبس النفس, حقق النصر, حمل, دعم, دفع, رافق, رحل, ساوى, سوق, شغل, صمد, طول, عانى, عبر, عتل, عزز, عقد, غضب, قاد, قاسى, قاوم, قبض على, كبت, كبح, كفى, لزم, مد يده, مشى, ملك, نجح في حمل, نشر, نقل, واكب, وسع, وقف, ولد
#          → [en] contain or hold; have within = hold, bear, carry
# [59 words] غاص, غار, غطس, غرِق, همد, نزل, أثر, أزال, أضعف, أضعف المعنويات, أطاح, إتخذ شكلا نهائيا, إستثمر أموالا, اخترق, اختفى, استعمر, استغرق, استقر, استوطن, انهار, تدنى, ترسخ, تطبع على, تعود, توطد, جلس في الكرسي, حط, حطم, حفر, حل, خسر, خفض, دخل, دمر سمعته, رص, سجل هدفا, سدد حسابا, سدد دين, سقط, سكن, سوى, صفى حسابا, غرز, غرق, غرق سفينة, غور, غوص, فصل, فور, قرر, قضى, قضى على, نسى, نظم, هدأ, هزم, وصى, وطن, وظف مالا
#          → [en] go under = sink, settle, go down
# [57 words] اِتّفق, تـطابق, توافق, أحبط, أعد, أقر, أوقف, إنسجم مع, إنطبق على, إنطبق على شكل, اتفق, انحرف, انسجم, بارى, تراسل, تطابق, تكيف, تماشى, تهكم, توصل إلى تسوية, جدول, جعله مطابقا, جهز, حسب, حسب النقاط, حقق, دون, رسم مربعات, زود, سحب مالا, سخر, سلم, ضبط, طابق الأرقام, عبر, عد, عرض الخصم للخطر, عنف, فحص, قارن, قمع, قيد, كافأ, كبت, كبح, لاءم, لائم, ماثل, ناسب, ناغم, نسق, هزأ ب, وازى, وافق, وبخ, ودع, وصل
#          → [en] be compatible, similar or consistent; coincid... = match, fit, correspond
# [57 words] تصوّر, تخيّل, أبدى للعيان, أدرك, أسقط, أصلح, أطلق, أولى الأمر عناية, اعتبر, بحث, برز, بصر, تجاوز, تحمل, تخيل, تدبر, تصور, تصور و يعتبر, تمثل, توهم, تيقن, جسد تمثال, جسم, جعل له نتوء, حسب, حقق, خطط, ذهب للسينما, رأى, رافق, رسم, رسم لوحة, رمى, زار, زين, سمح, شاهد, صمم, صور, ظن, ظهر ناتئا, عرض على الشاشة, عرض فلما, عرف, عزم, عكس صورة, عمل, عنى, فحص, فهم, قام بسلسلة حركات, قرر, لاحظ, لمح, نتأ, نوى, ولع ب
#          → [en] imagine; conceive of; see in one's mind = visualize, visualise, envision
# [56 words] أدّى إِلى, أسْفر عن, سبّب, تسبّب بِـ, تسبّب فِي, أحدث, أحرز هدفا, أدى, أسعد, أضرم, أعد للطبخ, أكرهه على, أنتج, أنهى, أيد فكرة ما, إتخذ قرارا, إندفع نحو, احتال, ارتكب, اعتبر, انتهى, اندفع, اهتم, بدأ عملا, بذل, بنى, تجبر, تصرف, تملق, تناول, جعل, جمل بمستحضرات تجميل, حضر, حول, خدع, خلق, ربح, رتب, زخرف, شن, صنع, ضم جهده, عوض, عين, غلق, فعل, قاضى, قام ب, قدم خدمة, نجح, نجز, نظف, نفذ, هيأ, وصل, وضع
#          → [en] give rise to; cause to happen or occur, not a... = cause, do, make
# [56 words] صبّ, جرى, سال, تدفّق, آكل, أدار, أذاب, أشبع, أطعم, أنسل, أيد ترشيح, إجتاز بسرعة, ارتفع, اقتات, انتشر, انزلق, بدأ العدو, تدلى, ترشح, تسرع, تصفح بسرعة, تكرر, تهدل, جري, حدث, حكم, خاض معركة, دخل, رسم خطا, رضى, ركض, سجل نقطة في البيسبول, سحب, سوق بسرعة, شجع, شغل, صب, صفى, صنف الأوراق, طارد, طبع, طعم, ظل نافذ المفعول, عبر, عجل, عدا, غذى, غمر, فاض, قاد, قاد السيارة, لقم, نشر, نما بسرعة, هرول, وقع
#          → [en] move along, of liquids = run, flow, feed
# [55 words] إِنْهار, اِنْكسر, تفتّت, تكسّر, تقطّع, أذاع, أرهق, أضعف, أوقف, إستبدل قطع النقد, استخلص, افترق, اقتحم, انتهك, انسحب, انفجر, انفصل, ترك, تفرق, تفكك, تفوق, تقطع, تكسر, جرح, جزأ, حطم, خرق, خفض السعر, دحض, روض, سحق, شق سطح كذا, شق طريقه, عزل عن بقية, عود, غير إتجاه شىء ما, فاصل, فر من, فرق, فرق الشمل, فصل, فضى بمكنون صدره, فك, فلس, قسم, قطع, قطع الصمت, كسر, كسر إضرابا, ميز, نزل رتبته, نصح, نقض, وضع حدا, وقع في الأفلاس
#          → [en] become separated into pieces or fragments = break, separate, split up
# [55 words] أدْرك, اِكْتشف, علِم, عرف, بلغ, سمِع, تلقّى, أدرك, أصغى, أصلح, أولى الأمر عناية, إستعاد صحته, استأنف, اعتبر, اعتقل, اقتنى, اكتشف, التقط, بحث, بصر, تحمل, تخيل, تدبر, تصور, تعرف لأصدقاء, تعلم, تعيش, تيقن, حفر, حفظ عن ظهر قلب, حقق, حمل الركاب, درس, رأى, رافق, رفع, زار, سمح, سمع, سمع الدعوى, شاهد, علا, علم من طريق السماع, عمل, عمل بحمية, عنى, فحص, فضى ب, فهم, كشف, كشف عن, لاحظ, لمح, نشط, وَجَدَ
#          → [en] get to know or become aware of, usually accid... = learn, hear, get word

# %% [markdown]
# <a id='taxonomy'></a>
# ## 6. Navigating the Taxonomy
#
# Since Arabic WordNet uses the "expand" methodology, it relies on the English WordNet for taxonomic relations (hypernyms/hyponyms). The relations are traversed using the Interlingual Index (ILI).

# %%
# Create Arabic wordnet with English as expand lexicon
arb_expanded = wn.Wordnet('omw-arb:1.4', expand='omw-en:1.4')

print("Lexicon configuration:")
print(f"  Primary: {arb_expanded.lexicons()}")
print(f"  Expanded: {arb_expanded.expanded_lexicons()}")
# Out:
# Lexicon configuration:
#   Primary: [<Lexicon omw-arb:1.4 [arb]>]
#   Expanded: [<Lexicon omw-en:1.4 [en]>]

# %%
# Find a synset and explore its hierarchy
print("\n🌳 Exploring Taxonomy")
print("=" * 60)

# Try to find a common noun with hypernyms
test_synsets = arb_expanded.synsets(pos='n')[:50]

for ss in test_synsets:
    hypernyms = ss.hypernyms()
    if hypernyms:
        lemmas = ', '.join([w.lemma() for w in ss.words()])
        defn, lang = get_definition(ss, en)
        lang_tag = f"[{lang}]" if lang else ""
        
        print(f"\n📌 {lemmas}")
        print(f"   Definition {lang_tag}: {defn}")
        print(f"   Hypernyms:")
        for h in hypernyms:
            h_lemmas = ', '.join([w.lemma() for w in h.words()])
            h_defn, h_lang = get_definition(h, en)
            h_en_words = get_english_words(h, en)
            h_display = h_lemmas if h_lemmas else f"[{', '.join(h_en_words[:3])}]" if h_en_words else "(no words)"
            print(f"     ↑ {h_display}: {h_defn[:50]}...")
        break
# Out:
# 🌳 Exploring Taxonomy
# ============================================================
#
# 📌 ظلْماء, دُهْمة, عتْمة, ظلام, ظُلْمة, غلس, قتْمة, ظَلْماء, دُهْمَة
#    Definition [en]: absence of light or illumination
#    Hypernyms:
#      ↑ إِضاءة: the degree of visibility of your environment...

# %% [markdown]
# <a id='crosslingual'></a>
# ## 7. Cross-Lingual Analysis (Arabic ↔ English)

# %%
# Find Arabic-English translations via ILI
print("🌐 Arabic → English Translations")
print("=" * 60)

count = 0
for ss in arb.synsets():
    if ss.ili and count < 15:
        # Find English equivalent
        en_synsets = en.synsets(ili=ss.ili.id)
        if en_synsets:
            arb_lemmas = ', '.join([w.lemma() for w in ss.words()])
            en_lemmas = ', '.join([w.lemma() for w in en_synsets[0].words()][:5])
            
            print(f"\n{arb_lemmas}")
            print(f"  → English: {en_lemmas}")
            print(f"  → ILI: {ss.ili.id}")
            count += 1
# Out:
# 🌐 Arabic → English Translations
# ============================================================
#
# أوّلِي, أَوَّلِي
#   → English: prime
#   → ILI: i17226
#
# ظلْماء, دُهْمة, عتْمة, ظلام, ظُلْمة, غلس, قتْمة, ظَلْماء, دُهْمَة
#   → English: dark, darkness
#   → ILI: i110421
#
# كِيْلُو مِتْر, كم
#   → English: kilometer, kilometre, km, klick
#   → ILI: i108497
#
# شارِي, مُشْترٍ, مُشْترِي
#   → English: buyer, purchaser, emptor, vendee
#   → ILI: i88763
#
# شائِك الجِلْد
#   → English: echinoderm
#   → ILI: i47722
#
# شذا, أرج, أرِيج, الرّائحة الزّكية, عبق, عبِير, عِطْر, حلاوة, طِيْب, باقة, ريّا, رِيْح
#   → English: bouquet, fragrance, fragrancy, redolence, sweetness
#   → ILI: i63173
#
# شأن, أهمِّيّة
#   → English: significance
#   → ILI: i64149
#
# شأن, همّ
#   → English: concern
#   → ILI: i66717
#
# شأن, شيء, أمْر, مسْألة
#   → English: matter, affair, thing
#   → ILI: i66720
#
# شأن, مسْألة, قضِيّة
#   → English: issue
#   → ILI: i67438
#
# شأن
#   → English: thing
#   → ILI: i67639
#
# شأْن, أمْر
#   → English: thing
#   → ILI: i110218
#
# شاء, أراد, رضِي, أسعد, أشبع, رضى, سر, عجب
#   → English: please
#   → ILI: i30850
#
# شاذّ, شخْص غرِيب الأطْوار, مهْوُس
#   → English: eccentric, eccentric person, flake, oddball, geek
#   → ILI: i89680
#
# شاع, ذاع, اِنْتشر
#   → English: break, get out, get around
#   → ILI: i26285

# %%
# English → Arabic translation
print("\n🌐 English → Arabic Translations")
print("=" * 60)

english_words = ['water', 'sun', 'moon', 'book', 'house', 'love', 'knowledge', 'work', 'big', 'small']

for en_word in english_words:
    en_synsets = en.synsets(en_word)
    
    if en_synsets:
        en_ss = en_synsets[0]  # Take first sense
        if en_ss.ili:
            # Find Arabic equivalent
            arb_synsets = arb.synsets(ili=en_ss.ili.id)
            if arb_synsets:
                arb_lemmas = ', '.join([w.lemma() for w in arb_synsets[0].words()])
                print(f"{en_word:15} → {arb_lemmas}")
            else:
                print(f"{en_word:15} → (not in Arabic WN)")
        else:
            print(f"{en_word:15} → (no ILI)")
# Out:
# 🌐 English → Arabic Translations
# ============================================================
# water           → ماء
# sun             → الأحد, يَوْم الأحَد
# moon            → ضُوء القمر, قمر
# book            → المُصْحف الشرِيف, القُرْآنُ الكرِيم, فُرْقان, مُصْحف, قُرْآن
# house           → بيْت, منْزِل
# love            → حُبّ
# knowledge       → إِدْراك, معْرِفة
# work            → شُغْل, عمل
# big             → كبِير
# small           → دقِيق, مِجْهرِي

# %%
# Coverage analysis - what percentage of English concepts have Arabic equivalents?
print("\n📊 Cross-Lingual Coverage Analysis")
print("=" * 50)

# Get all ILIs from Arabic
arb_ilis = set()
for ss in arb.synsets():
    if ss.ili and ss.ili.id:
        arb_ilis.add(ss.ili.id)

# Get all ILIs from English
en_ilis = set()
for ss in en.synsets():
    if ss.ili and ss.ili.id:
        en_ilis.add(ss.ili.id)

# Calculate overlap
common_ilis = arb_ilis & en_ilis

print(f"Arabic synsets with ILI:  {len(arb_ilis):,}")
print(f"English synsets with ILI: {len(en_ilis):,}")
print(f"Shared concepts (ILIs):   {len(common_ilis):,}")
print(f"\nArabic coverage of English: {len(common_ilis)/len(en_ilis)*100:.1f}%")
print(f"Arabic unique to Arabic:    {len(arb_ilis - en_ilis):,} concepts")
# Out:
# 📊 Cross-Lingual Coverage Analysis
# ==================================================
# Arabic synsets with ILI:  9,916
# English synsets with ILI: 117,659
# Shared concepts (ILIs):   9,916
#
# Arabic coverage of English: 8.4%
# Arabic unique to Arabic:    0 concepts

# %% [markdown]
# <a id='relations'></a>
# ## 8. Semantic Relations

# %%
# Explore different relation types available
print("🔗 Exploring Semantic Relations")
print("=" * 50)

# Collect all relation types found
all_relations = Counter()

for ss in list(arb_expanded.synsets())[:500]:
    rel_map = ss.relations()
    for rel_type in rel_map.keys():
        all_relations[rel_type] += len(rel_map[rel_type])

print("Relation types found (sample of 500 synsets):")
for rel_type, count in all_relations.most_common(20):
    print(f"  {rel_type:25} {count:5} instances")
# Out:
# 🔗 Exploring Semantic Relations
# ==================================================
# Relation types found (sample of 500 synsets):
#   hyponym                    3042 instances
#   hypernym                    458 instances
#   instance_hyponym            184 instances
#   mero_part                   133 instances
#   similar                     105 instances
#   holo_part                    51 instances
#   mero_member                  49 instances
#   domain_topic                 30 instances
#   attribute                    28 instances
#   has_domain_topic             28 instances
#   holo_member                  17 instances
#   instance_hypernym            11 instances
#   also                          8 instances
#   causes                        8 instances
#   entails                       7 instances
#   mero_substance                7 instances
#   holo_substance                6 instances
#   has_domain_region             2 instances
#   domain_region                 1 instances

# %%
# Explore specific relation examples
print("\n🔍 Relation Examples")
print("=" * 60)

def show_relations(synset, rel_type, limit=3):
    """Display relations of a specific type."""
    related = synset.get_related(rel_type)
    if related:
        for r in related[:limit]:
            lemmas = [w.lemma() for w in r.words()]
            if lemmas:
                print(f"    → {', '.join(lemmas)}")
            else:
                # Try English
                en_equiv = r.translate(lexicon='omw-en:1.4')
                if en_equiv:
                    en_lemmas = [w.lemma() for w in en_equiv[0].words()][:3]
                    print(f"    → [{', '.join(en_lemmas)}] (English)")

# Find a synset with various relations
for ss in arb_expanded.synsets(pos='n'):
    rels = ss.relations()
    if len(rels) >= 2:
        lemmas = ', '.join([w.lemma() for w in ss.words()])
        print(f"\nSynset: {lemmas}")
        print(f"Definition: {ss.definition() or '(no def)'}")
        
        for rel_type in list(rels.keys())[:5]:
            print(f"  {rel_type}:")
            show_relations(ss, rel_type)
        break
# Out:
# 🔍 Relation Examples
# ============================================================
#
# Synset: ظلْماء, دُهْمة, عتْمة, ظلام, ظُلْمة, غلس, قتْمة, ظَلْماء, دُهْمَة
# Definition: (no def)
#   hypernym:
#     → إِضاءة
#   hyponym:
#     → ليْل
#     → [total darkness, lightlessness, blackness] (English)
#     → [blackout, brownout, dimout] (English)

# %% [markdown]
# <a id='similarity'></a>
# ## 9. Similarity Measures

# %%
# Find pairs of Arabic synsets to compare
print("📐 Semantic Similarity Between Arabic Concepts")
print("=" * 60)

# Get some noun synsets with hypernyms
noun_synsets = []
for ss in arb_expanded.synsets(pos='n'):
    if ss.hypernyms() and ss.words():
        noun_synsets.append(ss)
    if len(noun_synsets) >= 10:
        break

if len(noun_synsets) >= 2:
    print("Comparing pairs of Arabic concepts:\n")
    
    for i in range(min(5, len(noun_synsets)-1)):
        ss1 = noun_synsets[i]
        ss2 = noun_synsets[i+1]
        
        lemma1 = ss1.words()[0].lemma()
        lemma2 = ss2.words()[0].lemma()
        
        try:
            path_sim = similarity.path(ss1, ss2)
            wup_sim = similarity.wup(ss1, ss2)
            
            print(f"{lemma1} ↔ {lemma2}")
            print(f"  Path similarity: {path_sim:.3f}")
            print(f"  Wu-Palmer:       {wup_sim:.3f}")
            print()
        except Exception as e:
            print(f"{lemma1} ↔ {lemma2}: Could not compute ({e})")
else:
    print("Not enough synsets with hypernyms found for similarity comparison.")
# Out:
# 📐 Semantic Similarity Between Arabic Concepts
# ============================================================
# Comparing pairs of Arabic concepts:
#
# ظلْماء ↔ كِيْلُو مِتْر
#   Path similarity: 0.091
#   Wu-Palmer:       0.286
#
# كِيْلُو مِتْر ↔ شارِي
#   Path similarity: 0.067
#   Wu-Palmer:       0.125
#
# شارِي ↔ شائِك الجِلْد
#   Path similarity: 0.111
#   Wu-Palmer:       0.600
#
# شائِك الجِلْد ↔ شذا
#   Path similarity: 0.071
#   Wu-Palmer:       0.133
#
# شذا ↔ شأن
#   Path similarity: 0.111
#   Wu-Palmer:       0.429

# %% [markdown]
# <a id='advanced'></a>
# ## 10. Advanced Analysis

# %%
# Character/script analysis of Arabic words
print("✍️ Arabic Script Analysis")
print("=" * 50)

import unicodedata

def analyze_arabic_text(text):
    """Analyze the Unicode properties of Arabic text."""
    categories = Counter()
    for char in text:
        cat = unicodedata.category(char)
        categories[cat] += 1
    return categories

# Collect all Arabic lemmas
all_lemmas = [word.lemma() for word in arb.words()]
all_text = ' '.join(all_lemmas)

# Analyze
char_stats = analyze_arabic_text(all_text)

print(f"Total Arabic words: {len(all_lemmas):,}")
print(f"Total characters:   {len(all_text):,}")
print(f"Unique characters:  {len(set(all_text))}")

print("\nCharacter categories:")
cat_names = {
    'Lo': 'Letters (other)',
    'Mn': 'Marks (non-spacing)',
    'Zs': 'Spaces',
    'Po': 'Punctuation',
    'Nd': 'Digits',
    'Lu': 'Letters (uppercase)',
    'Ll': 'Letters (lowercase)'
}
for cat, count in char_stats.most_common(10):
    name = cat_names.get(cat, cat)
    print(f"  {name:25} {count:6,} ({count/len(all_text)*100:.1f}%)")
# Out:
# ✍️ Arabic Script Analysis
# ==================================================
# Total Arabic words: 18,003
# Total characters:   173,821
# Unique characters:  79
#
# Character categories:
#   Letters (other)           113,868 (65.5%)
#   Marks (non-spacing)       34,065 (19.6%)
#   Spaces                    25,756 (14.8%)
#   Lm                            60 (0.0%)
#   Digits                        34 (0.0%)
#   Letters (uppercase)           14 (0.0%)
#   Pd                             8 (0.0%)
#   Punctuation                    8 (0.0%)
#   Letters (lowercase)            5 (0.0%)
#   So                             2 (0.0%)

# %%
# Word length distribution
print("\n📏 Word Length Distribution")
print("=" * 50)

lengths = [len(word.lemma()) for word in arb.words()]
length_dist = Counter(lengths)

print(f"Shortest word: {min(lengths)} characters")
print(f"Longest word:  {max(lengths)} characters")
print(f"Average:       {sum(lengths)/len(lengths):.1f} characters")

print("\nLength distribution:")
for length in sorted(length_dist.keys())[:15]:
    count = length_dist[length]
    bar = '█' * min(count // 20, 40)
    print(f"  {length:2} chars: {count:5} {bar}")

# Show longest words
print("\nLongest Arabic words:")
sorted_by_length = sorted([(word.lemma(), len(word.lemma())) for word in arb.words()], 
                          key=lambda x: x[1], reverse=True)
for word, length in sorted_by_length[:10]:
    print(f"  {word} ({length} chars)")
# Out:
# 📏 Word Length Distribution
# ==================================================
# Shortest word: 0 characters
# Longest word:  49 characters
# Average:       8.7 characters
#
# Length distribution:
#    0 chars:     3
#    1 chars:    13
#    2 chars:   121 ██████
#    3 chars:  1573 ████████████████████████████████████████
#    4 chars:  2034 ████████████████████████████████████████
#    5 chars:  2499 ████████████████████████████████████████
#    6 chars:  1736 ████████████████████████████████████████
#    7 chars:  1980 ████████████████████████████████████████
#    8 chars:  1215 ████████████████████████████████████████
#    9 chars:  1075 ████████████████████████████████████████
#   10 chars:   747 █████████████████████████████████████
#   11 chars:   718 ███████████████████████████████████
#   12 chars:   589 █████████████████████████████
#   13 chars:   587 █████████████████████████████
#   14 chars:   582 █████████████████████████████
#
# Longest Arabic words:
#   عاصِمة جُمْهُورِيّة الكُونْغُو الدِّيمُوقْراطِيّة (49 chars)
#   مُنظّمة الأُمم المُتّحِدة للتّقافة والعُلُوم (44 chars)
#   قُنْبُلَة أُنْبُوبِيَّة بَيْتِيَّة الصُّنْع (43 chars)
#   جُمْهُورِيّة سِيرِلانْكا الدِيمُوقْراطِيّة (42 chars)
#   جُمْهُورِيّة الكُونْغُو الدِّيمُوقْراطِيّة (42 chars)
#   اَلْٳمَارَاتُ ٱلْعَرَبِيَّةُ ٱلْمُتَّحِدَة (42 chars)
#   جِنْس نَبات من الفَصيلَةِ الفَرْبيُونِيَّة (42 chars)
#   وزارَة الصِّحَّة والخَدَمات الإنْسَانِيَّة (42 chars)
#   وَحْدَةُ قِياسِ الزَّاوِيَةِ المُجَسَّمَة (41 chars)
#   جُمْهُورِيّة يُوغُوسْلافْيا الإتِّحاديّة (40 chars)

# %%
# Export summary data
print("\n💾 Summary Export")
print("=" * 50)

import json

summary = {
    'lexicon': {
        'id': arb_lex.id,
        'version': arb_lex.version,
        'label': arb_lex.label,
        'language': arb_lex.language,
    },
    'statistics': {
        'words': arb_stats['words'],
        'senses': arb_stats['senses'],
        'synsets': arb_stats['synsets'],
        'nouns': arb_stats['words_n'],
        'verbs': arb_stats['words_v'],
        'adjectives': arb_stats['words_a'],
        'adverbs': arb_stats['words_r'],
    },
    'polysemy': {
        'monosemous': polysemy['monosemous'],
        'polysemous': polysemy['polysemous'],
        'avg_senses': round(polysemy['avg_senses'], 2),
        'max_senses': polysemy['max_senses'],
    },
    'cross_lingual': {
        'arabic_ilis': len(arb_ilis),
        'shared_with_english': len(common_ilis),
        'coverage_percent': round(len(common_ilis)/len(en_ilis)*100, 1) if en_ilis else 0,
    }
}

print(json.dumps(summary, indent=2, ensure_ascii=False))
# Out:
# 💾 Summary Export
# ==================================================
# {
#   "lexicon": {
#     "id": "omw-arb",
#     "version": "1.4",
#     "label": "Arabic WordNet (AWN v2)",
#     "language": "arb"
#   },
#   "statistics": {
#     "words": 18003,
#     "senses": 37342,
#     "synsets": 9916,
#     "nouns": 10344,
#     "verbs": 6728,
#     "adjectives": 693,
#     "adverbs": 238
#   },
#   "polysemy": {
#     "monosemous": 12591,
#     "polysemous": 5412,
#     "avg_senses": 2.07,
#     "max_senses": 48
#   },
#   "cross_lingual": {
#     "arabic_ilis": 9916,
#     "shared_with_english": 9916,
#     "coverage_percent": 8.4
#   }
# }

# %% [markdown]
# ---
#
# ## 📋 Summary
#
# In this notebook, we explored the **Arabic WordNet (AWN v2)** using the `wn` library:
#
# ### Key Findings:
# 1. **Coverage**: The Arabic WordNet provides Arabic lexical entries linked to English concepts via ILI
# 2. **Structure**: Uses the "expand" methodology - Arabic words are added on top of English synset structure
# 3. **Relations**: Taxonomic relations (hypernyms/hyponyms) are inherited from the English WordNet
# 4. **Cross-lingual**: Full bidirectional translation capability between Arabic and English
#
# ### Next Steps:
# - Compare with other Arabic NLP resources
# - Build Arabic word sense disambiguation systems
# - Use for Arabic-English machine translation
# - Extend coverage by proposing new Arabic entries
#
# ### Resources:
# - [wn Documentation](https://wn.readthedocs.io/)
# - [Open Multilingual Wordnet](https://github.com/omwn/omw-data)
# - [Arabic WordNet Project](http://www.globalwordnet.org/AWN/)
